# %%
import pandas as pd

# %%
# first import all necessary libraries
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
target=pd.read_csv('IBADAN-OYO-OGBOMOSO-ILORIN RTC DATA  (2018-2011).csv')

# %%
target.head()
# Out:
#                                     ZONE RS11 OSOGBO Unnamed: 1 Unnamed: 2  \
# 0  2018 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC C...        NaN        NaN
# 1                                                S/N    COMMAND       DATE
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                  a          b          c
#
#   Unnamed: 3        Unnamed: 4 Unnamed: 5 Unnamed: 6      Unnamed: 7  \
# 0        NaN               NaN        NaN        NaN             NaN
# 1        DAY  CRASH TIME (HRS)      ROUTE   LOCATION  VEHICLE NUMBER
# 2        NaN               NaN        NaN        NaN             NaN
# 3        NaN               NaN        NaN        NaN             NaN
# 4          c                 d          h          i               j
#
#        Unnamed: 8     Unnamed: 9  ... Unnamed: 26 Unnamed: 27  \
# 0             NaN            NaN  ...         NaN         NaN
# 1  VEHICLE NUMBER  VEHICLE CLASS  ...         NaN         NaN
# 2             NaN            NaN  ...         NaN       TOTAL
# 3             NaN            NaN  ...           F         NaN
# 4               j              k  ...          ab          ac
#
#        Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0              NaN         NaN         NaN         NaN         NaN
# 1  PEOPLE INVOLVED         NaN         NaN         NaN         NaN
# 2            ADULT         NaN       CHILD         NaN       TOTAL
# 3                M           F           M           F         NaN
# 4               ad          ae          af          ag          ah
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0         NaN         NaN         NaN
# 1   RTC TYPE          NaN         NaN
# 2         NaN         NaN         NaN
# 3           F           S           M
# 4          ai          aj          ak
#
# [5 rows x 36 columns]

# %%
target
# Out:
#                                       ZONE RS11 OSOGBO Unnamed: 1 Unnamed: 2  \
# 0    2018 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC C...        NaN        NaN
# 1                                                  S/N    COMMAND       DATE
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                    a          b          c
# 5                                                    1    RS11.31   01/01/18
# 6                                                    2    RS11.39   03/01/18
# 7                                                    3    RS11.31   03/01/18
# 8                                                    4    RS11.38   04/01/18
# 9                                                    5    RS11.38   06/01/18
# 10                                                   6    RS11.31   07/01/18
# 11                                                   7    RS11.39   10/01/18
# 12                                                   8    RS11.39   10/01/18
# 13                                                   9    RS11.39   12/01/18
# 14                                                  10    RS11.39   15/01/18
# 15                                                  11    RS11.31   17/01/18
# 16                                                  12    RS11.39   22/01/18
# 17                                                  13    RS11.38   24/01/18
# 18                                                  14    RS11.31   27/01/18
# 19                                                  15    RS11.38   28/01/18
# 20                                                  16    RS11.38   30/01/18
# 21                                                  17    RS11.31   08/02/18
# 22                                                  18    RS11.38   09/02/18
# 23                                                  19    RS11.38   14/02/18
# 24                                                  20    RS11.31   18/02/18
# 25                                                  21    RS11.31   18/02/18
# 26                                                  22    RS11.31   20/02/18
# 27                                                  23    RS11.31   20/02/18
# 28                                                  24    RS11.31   21/02/18
# 29                                                  25    RS11.38   24/02/18
# ..                                                 ...        ...        ...
# 122                                                118    RS11.31   05/10/18
# 123                                                119    RS11.38   07/10/18
# 124                                                120    RS11.38   09/10/18
# 125                                                121    RS11.38   09/10/18
# 126                                                122    RS11.38   10/10/18
# 127                                                123    RS11.38   11/10/18
# 128                                                124    RS11.31   13/10/18
# 129                                                125    RS11.31   14/10/18
# 130                                                126    RS11.31   17/10/18
# 131                                                127    RS11.31   17/10/18
# 132                                                128    RS11.38   18/10/18
# 133                                                129    RS11.39   25/10/18
# 134                                                130    RS11.39   08/11/18
# 135                                                131    RS11.38   10/11/18
# 136                                                132    RS11.31   13/11/18
# 137                                                133    RS11.38   14/11/18
# 138                                                134    RS11.31   19/11/18
# 139                                                135    RS11.38   20/11/18
# 140                                                136    RS11.39   24/11/18
# 141                                                137    RS11.38   09/12/18
# 142                                                138    RS11.39   10/12/18
# 143                                                139    RS11.31   11/12/18
# 144                                                140    RS11.38   11/12/18
# 145                                                141    RS11.31   11/12/18
# 146                                                142    RS11.31   16/12/18
# 147                                                143    RS11.31   30/12/18
# 148                                 TOTAL FOR THE YEAR        NaN        NaN
# 149                                                NaN        NaN        NaN
# 150                                                NaN        NaN        NaN
# 151                                                NaN        NaN        NaN
#
#     Unnamed: 3        Unnamed: 4 Unnamed: 5  \
# 0          NaN               NaN        NaN
# 1          DAY  CRASH TIME (HRS)      ROUTE
# 2          NaN               NaN        NaN
# 3          NaN               NaN        NaN
# 4            c                 d          h
# 5          MON              0855    OGB-OYO
# 6          WED              1040    OYO-IBD
# 7          WED              1121    OGB-OYO
# 8          THU              1425    OYO-OGB
# 9          SAT              1650    OYO-OGB
# 10         SUN              0325    OGB-OYO
# 11         WED              0740    IBD-OYO
# 12         WED              0930    IBD-OYO
# 13         FRI              1150    IBD-OYO
# 14         MON              1940    OYO-IBD
# 15         WED              1625    OGB-ILN
# 16         MON              0600    OYO-IBD
# 17         WED              1630    OYO-OGB
# 18         SAT              1705    OGB-OYO
# 19         SUN              0752    OYO-OGB
# 20         TUE              0900    OYO-OGB
# 21         THU              0910    OGB-OYO
# 22         FRI              0355    OYO-OGB
# 23         WED              1255    OYO-OGB
# 24         SUN              1145    OGB-OYO
# 25         SUN              1730    OGB-OYO
# 26         TUE              1830    OGB-ILN
# 27         TUE              2330    OGB-ILN
# 28         WED              1032    OGB-ILN
# 29         SAT              0935    OYO-OGB
# ..         ...               ...        ...
# 122        FRI              1737    OGB-OYO
# 123        SUN              1030    OYO-IBD
# 124        TUE              0832    OYO-IBD
# 125        TUE              1125    OYO-OGB
# 126        WED              1045    OYO-IBD
# 127        THU              1645    OYO-OGB
# 128        SAT              2025    OGB-ILN
# 129        SUN              1630    OGB-ILN
# 130        WED              0649    OGB-OYO
# 131        WED              1025    OGB-OYO
# 132        THU              1720    OYO-OGB
# 133        THU              1330    OYO-IBD
# 134        THU              1359    OYO-IBD
# 135        SAT              1032    OYO-OGB
# 136        TUE              0630    OGB-ILN
# 137        WED              1431    OYO-OGB
# 138        MON              0835    OGB-OYO
# 139        TUE              1320    OYO-OGB
# 140        SAT              1750    OYO-IBD
# 141        SUN              1020    OYO-IBD
# 142        MON              1250    OYO-IBD
# 143        TUE              0328    OGB-OYO
# 144        TUE              1620    OYO-IBD
# 145        TUE              2124    OGB-OYO
# 146        SUN              1310    OGB-OYO
# 147        SUN              1140    OGB-OYO
# 148        NaN               NaN        NaN
# 149        NaN               NaN        NaN
# 150        NaN               NaN        NaN
# 151        NaN               NaN        NaN
#
#                              Unnamed: 6      Unnamed: 7  \
# 0                                   NaN             NaN
# 1                              LOCATION  VEHICLE NUMBER
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                     i               j
# 5                            KM7-IBAPON               2
# 6               KM5 4RM IBD-MOBILE AREA               3
# 7                            KM7-IBAPON               1
# 8                KM2-ODO ASHIPA VILLAGE               3
# 9              KM3-FED LOW COST HOUSING               2
# 10                            KM5-AGRIC               1
# 11                 KM7-DEPEER LIFE AREA               1
# 12                       KM5-TOSHE AREA               2
# 13                  OLD RD BY BANK JCTN               2
# 14                4KM 4RM IBD-NNPC JCTN               1
# 15                   KM10-AROJE EXPRESS               2
# 16                 10KM 4RM IBD-ABE ODO               7
# 17                  KM21-BUSARI VILLAGE               2
# 18                  KM12-ISANLA VILLAGE               2
# 19                     KM4-CUSTOMS AREA               2
# 20                      KM1-DURBAR AREA               2
# 21                           KM9-SEKONA               1
# 22                         KM17-ONIGARI               2
# 23                 KM10.3-IDODE VILLAGE               2
# 24                       KM5-ARINKINKIN               1
# 25                           KM12-ELEGA               2
# 26                          KM19-ABDUKA               1
# 27                    KM8-AROJE VILLAGE               1
# 28                         KM19.5-GBEDE               1
# 29                      KM2-CUSTOM AREA               1
# ..                                  ...             ...
# 122        KM10-ILE-ABU VILLAGE/ODO-OBA               3
# 123                         KM18-FIDITI               1
# 124                         KM11-JOBELE               1
# 125                         KM10-AGBOYE               1
# 126                    KM1-ILORA BRIDGE               2
# 127              KM1-SCH OF SURVEY AREA               2
# 128                    KM1-ODO ORU JCTN               1
# 129        KM1-RANDAH R/A BY BOWEN HOSP               1
# 130                 KM8- AJE IYA FUEL/S               2
# 131                      KM7.5 -ARINKIN               1
# 132               KM12.3-AGBOYE VILLAGE               1
# 133  KM16-IROKO AFTER KOLADAISI VERSITY               1
# 134                               IROKO               2
# 135                KM16-IJAWAYA VILLAGE               1
# 136               KM10-MECHANIC VILLAGE               2
# 137                   KM11.5-ABA LAWYER               2
# 138                KM8.5-SEKONA VILLAGE               3
# 139                     KM2-CUSTOM AREA               1
# 140                    5KM 4RM OJOO-RCC               1
# 141                         KM17-FIDITI               1
# 142  10KM 4RM IBD-AKINYELE UNDER BRIDGE               2
# 143              KM15-OOLO COM GRAM SCH               2
# 144                    KM7-ILORA BRIDGE               2
# 145            KM17-ASANI ELEGA VILLAGE               1
# 146                 KM4.5-HIGH SCH JCTN               1
# 147                       KM5-FRSC BASE               2
# 148                                 NaN             236
# 149                                 NaN             NaN
# 150                                 NaN             NaN
# 151                                 NaN             NaN
#
#                                             Unnamed: 8  \
# 0                                                  NaN
# 1                                       VEHICLE NUMBER
# 2                                                  NaN
# 3                                                  NaN
# 4                                                    j
# 5                             KJA166XM/       WDL522XA
# 6                     KTN207XA/ BDU341XA.     EKY309ZF
# 7                                             XA365KMB
# 8                            KSF87QX/     XB624KMA/ NA
# 9                                DKA129XF/    AAA146FB
# 10                                            BDU660ZQ
# 11                                            BDJ430ZQ
# 12                                LND843XA/         NA
# 13                                AG801RUM/   KTU429EZ
# 14                                            KSF591XG
# 15                               AA471BDA/    LND554ER
# 16   KRD804BG/         EPE997DB/        LSR30XA/   ...
# 17                             XE455PFA/      LKJ790XU
# 18                              JJJ318XR/     XB286RLG
# 19                          KNK153XA/         BDG722QH
# 20                          AG995FUF/         DTN711QC
# 21                                             FFA72BW
# 22                 NA/                        LEM563XA
# 23                              JJJ732XF/     LGB210XA
# 24                                               UNREG
# 25                             MUS700XV/      KNR396XA
# 26                                            XB277BDA
# 27                                             EPE46QB
# 28                                            MNA442XV
# 29                                            KJA570XW
# ..                                                 ...
# 122  KJM99XA/          EPE872EU/                 BD...
# 123                                           AFN734XA
# 124                                           AGL419XN
# 125                                           RMY228XA
# 126                            EKY892DK/            NA
# 127                         LND934XV/         OY7550YC
# 128                                           AAW480AA
# 129                                           TDE315AA
# 130                              XB397KKY/    KTU220XC
# 131                                                NaN
# 132                                           MUS490BP
# 133                                           XB218BBJ
# 134                            EPE348AP/      LSR411XJ
# 135                                           WDL674XA
# 136                             GZW45XA/      XC324KTC
# 137                              NSD309XT/    KTU455XM
# 138          GGE869FK/       TTN731QE/        KEY992DS
# 139                                           YH506EPE
# 140                                            OY19A41
# 141                                            APP47DR
# 142                              BKD361XA/    PMD208XA
# 143                                  NA/      AME746XA
# 144                           EKY166XV/       YYY488XA
# 145                                           ARP716XA
# 146                                            KWL62ZA
# 147                        SMK406XQ/          LRN952NK
# 148                                                  0
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
#
#                                             Unnamed: 9  ... Unnamed: 26  \
# 0                                                  NaN  ...         NaN
# 1                                        VEHICLE CLASS  ...         NaN
# 2                                                  NaN  ...         NaN
# 3                                                  NaN  ...           F
# 4                                                    k  ...          ab
# 5                                         COMM/   COMM  ...           0
# 6                                      COMM/COMM/ COMM  ...           0
# 7                                                 COMM  ...           0
# 8                                COMM/    COMM/   COMM  ...           0
# 9                                          COMM/   PVT  ...           0
# 10                                                 PVT  ...           0
# 11                                                COMM  ...           0
# 12                                       COMM/    GOVT  ...           0
# 13                                          PVT/   PVT  ...           0
# 14                                                COMM  ...           0
# 15                                          PVT/   PVT  ...           0
# 16   PVT/    PVT/    COMM/    COMM/       COMM/    ...  ...           0
# 17                                         COMM/  COMM  ...           0
# 18                                         COMM/  COMM  ...           0
# 19                                       COMM/    COMM  ...           0
# 20                                   PVT/         COMM  ...           0
# 21                                                 PVT  ...           0
# 22                                        COMM/   COMM  ...           0
# 23                                         COMM/  COMM  ...           0
# 24                                                COMM  ...           0
# 25                                         COMM/  COMM  ...           0
# 26                                                COMM  ...           0
# 27                                                 PVT  ...           0
# 28                                                COMM  ...           0
# 29                                                COMM  ...           0
# ..                                                 ...  ...         ...
# 122                                COMM/   PVT/   COMM  ...           0
# 123                                               COMM  ...           0
# 124                                               COMM  ...           0
# 125                                               COMM  ...           0
# 126                                        COMM/  COMM  ...           0
# 127                                       COMM/    PVT  ...           0
# 128                                                PVT  ...           0
# 129                                                PVT  ...           0
# 130                                       COMM/   COMM  ...           0
# 131                                       COMM/   COMM  ...           0
# 132                                                PVT  ...           1
# 133                                               COMM  ...           0
# 134                                       PVT/     PVT  ...           0
# 135                                               COMM  ...           0
# 136                                        COMM/  COMM  ...           0
# 137                                        COMM/  COMM  ...           0
# 138                          PVT/       COMM/      PVT  ...           0
# 139                                               COMM  ...           0
# 140                                                PVT  ...           0
# 141                                                PVT  ...           0
# 142                                        COMM/  COMM  ...           0
# 143                                        COMM/  COMM  ...           0
# 144                                        COMM/  COMM  ...           0
# 145                                        COMM/  COMM  ...           0
# 146                                               COMM  ...           0
# 147                                       COMM/    PVT  ...           0
# 148                                                  0  ...           3
# 149                                                NaN  ...         NaN
# 150                                                NaN  ...         NaN
# 151                                                NaN  ...         NaN
#
#     Unnamed: 27      Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0           NaN              NaN         NaN         NaN         NaN
# 1           NaN  PEOPLE INVOLVED         NaN         NaN         NaN
# 2         TOTAL            ADULT         NaN       CHILD         NaN
# 3           NaN                M           F           M           F
# 4            ac               ad          ae          af          ag
# 5             0               22           0           0           0
# 6             0               10          20           0           0
# 7             0                4           0           0           0
# 8             0                6           0           2           0
# 9             0                5           1           0           1
# 10            3                6           1           0           1
# 11            1                1           0           0           0
# 12            0               30           0           0           0
# 13            0                5           0           0           0
# 14            1                2           0           0           0
# 15            0                5           0           0           0
# 16            4               28           4           0           0
# 17            3               11           4           0           0
# 18            0               17           4           1           0
# 19            0                5           1           0           1
# 20            0                3           1           0           0
# 21            0                2           0           0           0
# 22            0               19           0           0           0
# 23            0               19          16           0           1
# 24            1                1           0           0           0
# 25            0               18          10           0           0
# 26            4               16           0           0           0
# 27            0                4           0           0           0
# 28            1                3           2           0           0
# 29            0                2           0           0           0
# ..          ...              ...         ...         ...         ...
# 122           0                9           2           0           0
# 123           0                8           6           1           1
# 124           1                8           5           0           0
# 125           0               12           1           0           0
# 126           0                3           1           0           0
# 127           1                2           0           0           0
# 128           1                3           1           0           0
# 129           1                5           0           0           0
# 130           8                6           3           3           0
# 131           2                4           0           0           0
# 132           2                1           1           0           1
# 133           2                8           9           0           0
# 134           0                2           0           0           0
# 135           1                3           0           0           0
# 136           6               22           0           0           0
# 137           3                3           3           0           0
# 138           0                6           0           0           0
# 139           0               10           8           0           0
# 140           1                2           0           0           0
# 141           3                7           0           0           0
# 142           4                7           0           0           0
# 143           0               10           3           0           0
# 144           2                7           1           7           2
# 145           0                2           6           0           0
# 146           0                3           0           0           0
# 147           0                8           6           0           0
# 148         115              947         255          25          21
# 149         NaN              NaN         NaN         NaN         NaN
# 150         NaN              NaN         NaN         NaN         NaN
# 151         NaN              NaN         NaN         NaN         NaN
#
#     Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0           NaN         NaN         NaN         NaN
# 1           NaN   RTC TYPE          NaN         NaN
# 2         TOTAL         NaN         NaN         NaN
# 3           NaN           F           S           M
# 4            ah          ai          aj          ak
# 5            22           0           1           0
# 6            30           0           1           0
# 7             4           0           1           0
# 8             8           0           1           0
# 9             7           0           1           0
# 10            8           0           1           0
# 11            1           1           0           0
# 12           30           0           1           0
# 13            5           0           1           0
# 14            2           1           0           0
# 15            5           0           1           0
# 16           32           1           0           0
# 17           15           1           0           0
# 18           22           0           1           0
# 19            7           0           1           0
# 20            4           0           1           0
# 21            2           0           1           0
# 22           19           0           1           0
# 23           36           0           1           0
# 24            1           1           0           0
# 25           28           0           1           0
# 26           16           1           0           0
# 27            4           0           1           0
# 28            5           1           0           0
# 29            2           0           1           0
# ..          ...         ...         ...         ...
# 122          11           0           1           0
# 123          16           0           1           0
# 124          13           1           0           0
# 125          13           0           1           0
# 126           4           0           1           0
# 127           2           1           0           0
# 128           4           1           0           0
# 129           5           1           0           0
# 130          12           1           0           0
# 131           4           1           0           0
# 132           3           1           0           0
# 133          17           1           0           0
# 134           2           0           1           0
# 135           3           1           0           0
# 136          22           1           0           0
# 137           6           1           0           0
# 138           6           0           1           0
# 139          18           0           1           0
# 140           2           1           0           0
# 141           7           1           0           0
# 142           7           1           0           0
# 143          13           0           1           0
# 144          17           1           0           0
# 145           8           0           1           0
# 146           3           0           0           1
# 147          14           0           0           1
# 148        1248          62          74           7
# 149         NaN         NaN         NaN         NaN
# 150         NaN         NaN         NaN         NaN
# 151         NaN         NaN         NaN         NaN
#
# [152 rows x 36 columns]

# %%
target1=pd.read_csv('IBADAN-OYO-OGBOMOSO-ILORIN RTC DATA  (2017).csv')

# %%
target1
# Out:
#                                       ZONE RS11 OSOGBO Unnamed: 1  Unnamed: 2  \
# 0    2017 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC C...        NaN         NaN
# 1                                                  S/N    COMMAND        DATE
# 2                                                  NaN        NaN         NaN
# 3                                                  NaN        NaN         NaN
# 4                                                    a          b           c
# 5                                                    1    RS11.39  01/01/2017
# 6                                                    2    RS11.38  01/01/2017
# 7                                                    3    RS11.31  08/01/2017
# 8                                                    4    RS11.31  14/01/2017
# 9                                                    5    RS11.38  18/01/2017
# 10                                                   6    RS11.38  20/01/2017
# 11                                                   7    RS11.38  26/01/2017
# 12                                                   8    RS11.38  28/01/2017
# 13                                                   9    RS11.38  29/01/2017
# 14                                                  10    RS11.31  30/01/2017
# 15                                                  11    RS11.38  04/02/2017
# 16                                                  12    RS11.31  04/02/2017
# 17                                                  13    RS11.39  07/02/2017
# 18                                                  14    RS11.38  12/02/2017
# 19                                                  15    RS11.31  13/02/2017
# 20                                                  16    RS11.31  15/02/2017
# 21                                                  17    RS11.38  16/02/2017
# 22                                                  18    RS11.31  20/02/2017
# 23                                                  19    RS11.38  22/02/2017
# 24                                                  20    RS11.31  23/02/2017
# 25                                                  21    RS11.31  03/03/2017
# 26                                                  22    RS11.38  04/03/2017
# 27                                                  23    RS11.31  10/03/2017
# 28                                                  24    RS11.39  14/03/2017
# 29                                                  25    RS11.39  14/03/2017
# ..                                                 ...        ...         ...
# 90                                                  86    RS11.31  18/08/2017
# 91                                                  87    RS11.38  23/08/2017
# 92                                                  88    RS11.38  28/08/2017
# 93                                                  89    RS11.39  30/08/2017
# 94                                                  90    RS11.38  30/08/2017
# 95                                                  91    RS11.39  02/09/2017
# 96                                                  92    RS11.31  05/09/2017
# 97                                                  93    RS11.31  17/09/2017
# 98                                                  94    RS11.39  24/09/2017
# 99                                                  95    RS11.38  25/09/2017
# 100                                                 96    RS11.38  04/10/2017
# 101                                                 97    RS11.38  10/10/2017
# 102                                                 98    RS11.38  10/10/2017
# 103                                                 99    RS11.38  17/10/2017
# 104                                                100    RS11.38  18/10/2017
# 105                                                101    RS11.38  02/11/2017
# 106                                                102    RS11.31  07/11/2017
# 107                                                103    RS11.38  27/11/2017
# 108                                                104    RS11.31  29/11/2017
# 109                                                105    RS11.38  15/12/2017
# 110                                                106    RS11.38  18/12/2017
# 111                                                107    RS11.39  19/12/2017
# 112                                                108    RS11.38  20/12/2017
# 113                                                109    RS11.38  21/12/2017
# 114                                                110    RS11.31  22/12/2017
# 115                                                111    RS11.31  23/12/2017
# 116                                                112    RS11.39  26/12/2017
# 117                                                113    RS11.31  28/12/2017
# 118                                                114    RS11.38  29/12/2017
# 119                                 TOTAL FOR THE YEAR        NaN         NaN
#
#     Unnamed: 3        Unnamed: 4 Unnamed: 5                   Unnamed: 6  \
# 0          NaN               NaN        NaN                          NaN
# 1          DAY  CRASH TIME (HRS)      ROUTE                     LOCATION
# 2          NaN               NaN        NaN                          NaN
# 3          NaN               NaN        NaN                          NaN
# 4            c                 d          h                            i
# 5          SUN               740    IBD-OYO                         TOSE
# 6          SUN              1326    OYO-OGB                   KM8-AGBOYE
# 7          SUN              1303    OGB-ILN                    KM5-TAKIE
# 8          SAT              1040    OGB-OYO                 15KM-ODO OBA
# 9          WED               406    OYO-OGB                 KM11-LAWYER
# 10         FRI               541    OYO-OGB           KM25-IPEBA VILLAGE
# 11         THU              1111    OYO-OGB                 KM18-ALAIDAN
# 12         SAT              1012    OYO-IBD                   KM2-OLIVET
# 13         SUN              1420    OYO-IBD                  KM12-JOBELE
# 14         MON               130    OGB-OYO              KM3-AJAIYA AREA
# 15         SAT               822    OYO-IBD                 KM10-ELEKARA
# 16         SAT              1910    OGB-OYO               KM6-AGRIC AREA
# 17         TUE              1545    OYO-IBD             DEEPER LIFE JCTN
# 18         SUN              1258    OYO-OGB           KM17-OWEYO VILLAGE
# 19         MON              1810    OGB-OYO           KM1.5-HIGH  SCHOOL
# 20         WED              1550    OGB-ILN                      KM6-GTB
# 21         THU                20    OYO-OGB          KM22-ALABON VILLAGE
# 22         MON              1304    OGB-OYO                    FRSC BASE
# 23         WED               201    OYO-IBD                  KM12-JOBELE
# 24         THU               930    OGB-OYO                 KM20HIGH SCH
# 25         FRI              2134    OGB-OYO                  KM6-ILE ABU
# 26         SAT              1211    OYO-OGB                 KM15-IJAWAYA
# 27         FRI              1816    OGB-ILN                 KM8-OJA WASO
# 28         TUE              1330    IBD-OYO                ISAJOG FUEL/S
# 29         TUE              2205    IBD-OYO        AKINYELE UNDER BRIDGE
# ..         ...               ...        ...                          ...
# 90         FRI              1630    OGB-OYO          KM6-ILE ABU, SEKONA
# 91         WED               730    OYO-IBD                  KM18-FIDITI
# 92         MON               733    OYO-OGB                  KM3-OLALOMI
# 93         WED               950    IBD-OYO        KM3- OPP RCC, IDI OSE
# 94         WED              1043    OYO-IBD                  KM15-JOBELE
# 95         SAT              1445    IBD-OYO         KM5-POWER LINE, LABI
# 96         TUE               900    OGB-ILN  3KM 4RM LAUTH-AROJE VILLAGE
# 97         SUN               410    OGB-OYO           KM 3-HIGH SCH JUCT
# 98         SUN               900    OYO-IBD        6KM FROM IBD-AKINYELE
# 99         MON              1330    OYO-OGB                 KM17-ALAGBON
# 100        WED              2100    OYO-OGB                  KM6-OFAMETA
# 101        TUE               610    OYO-OGB              KM6-BODE THOMAS
# 102        TUE              1505    OYO-IBD                  KM14-FIDITI
# 103        TUE              1146    OYO-OGB              KM2-ORIAWO JCTN
# 104        WED              1255    OYO-OGB            KM13.3-ABA LAWYER
# 105        THU              1415    OYO-OGB             KM13-CUSTOM AREA
# 106        TUE              1020    OGB-OYO         KM21-IDI EMI VILLAGE
# 107        MON              1406    OYO-OGB         KM12-ALAIDAN VILLAGE
# 108        WED               428    OGB-OYO          KM15-ALAYIN VILLAGE
# 109        FRI               944    OYO-OGB          KM33-LAWYER VILLAGE
# 110        MON              1015    OYO-OGB          KM2-PACIFIC ACADEMY
# 111        TUE               445    OYO-IBD      5KM 4RM IBD-DEEPER LIFE
# 112        WED               845    OYO-IBD            KM7-OMOTUNDE AREA
# 113        THU              1340    OYO-OGB              KM17-ABA LAWYER
# 114        FRI              2040    OGB-OYO          KM12-IBAPON VILLAGE
# 115        SAT              1320    OGB-OYO     KM2.5-AJE IYA FUEL STATE
# 116        TUE               720    IBD-OYO       KM20-AKINYELE TRL PARK
# 117        THU              1300    OGB-OYO           KM20-IPEBA VILLAGE
# 118        FRI              1510    OYO-OGB           KM40-OWOYO VILLAGE
# 119        NaN               NaN        NaN                          NaN
#
#          Unnamed: 7                                         Unnamed: 8  \
# 0               NaN                                                NaN
# 1    VEHICLE NUMBER                                     VEHICLE NUMBER
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4                 j                                                  j
# 5                 1                                           MUS238DA
# 6                 2                              KSF384BR/    GMD202XA
# 7                 2                               KWL549XA/   BDS212XA
# 8                 1                                           KRD180XB
# 9                 1                                           LSR711BV
# 10                3                  OKA875ZU/    KNH387XA/   SMK401XA
# 11                1                                           RAN248XA
# 12                2                           FKJ310XA/       OY6985AA
# 13                2                           NPF1216/         FN99EKY
# 14                1                                           DKA473ZU
# 15                2                            TRN359ZG/      JJJ102CY
# 16                2                             KJA775XJ/     KJA978XK
# 17                2                         SUL372XA/         EPE222DJ
# 18                3                     NA/      BDG229XQ/    DUT285XA
# 19                1                                                NaN
# 20                7  APP995XP/  LND517AU/  SMK468CW/   RSD296AAA/  ...
# 21                1                                           AA602MHT
# 22                2                              AGL247XP/    AJ394KNH
# 23                1                                           XA380KNK
# 24                2                                      EKY321QB/  NA
# 25                1                                           XC321MNY
# 26                1                                           RBC662XP
# 27                1                                           KSF221DV
# 28                1                                   EPE885XG/
# 29                2                               SNN28XA/    JJJ804XQ
# ..              ...                                                ...
# 90                2                 NA/                       LSD471DY
# 91                1                                             KTU874
# 92                1                                                NaN
# 93                2                                  KEH630QC/      NA
# 94                1                                           EKY824XD
# 95                2                        KJA307BF/          AKD755DM
# 96                2                              SEY211AA/    OY6865RS
# 97                2                           AA284FFE/       SUL444XA
# 98                2                              LSD817ER/    BDU714XA
# 99                1                                           LRN651XA
# 100               1                                           XG145MKA
# 101               3                BNZ887CA/    XA503KUR/     NRR915YQ
# 102               1                                           BDS193XA
# 103               1                                           XA200GWD
# 104               1                                           LEM540XA
# 105               2                              ARP705XA/    FMT731QC
# 106               2                               KRA174XA/    KWN65ZA
# 107               2                             KMC02YQ/      GWL161YJ
# 108               2                          NA/               JAL917X
# 109               3                  KNH373XA/     EPE142XQ/  LSR813DZ
# 110               1                                           NSR728ZD
# 111               1                                            KTN79XA
# 112               1                                           XA170AKD
# 113               2                                 LSD365AC/ MUM730XA
# 114               2                               AKD502XN/   LEM573XA
# 115               2                           FKJ289XC/       KRD183EY
# 116               2                                FTA668XA/        NA
# 117               3                  APP321CF/     KRD362XM/  EPE194XQ
# 118               2                              MKA292XH/    LSR861EL
# 119             202                                                  0
#
#                                             Unnamed: 9  ... Unnamed: 26  \
# 0                                                  NaN  ...         NaN
# 1                                        VEHICLE CLASS  ...         NaN
# 2                                                  NaN  ...         NaN
# 3                                                  NaN  ...           F
# 4                                                    k  ...          ab
# 5                                                  PVT  ...           0
# 6                                        PVT/     COMM  ...           0
# 7                                         COMM/   COMM  ...           0
# 8                                                 COMM  ...           1
# 9                                                  PVT  ...           0
# 10                                  COMM/  COMM/  COMM  ...           0
# 11                                                COMM  ...           0
# 12                                        COMM/   COMM  ...           0
# 13                                       GOVT/     PVT  ...           0
# 14                                                COMM  ...           0
# 15                                         COMM/   PVT  ...           0
# 16                                         COMM/  COMM  ...           0
# 17                                         COMM/   PVT  ...           0
# 18                                 COMM/   COMM/  COMM  ...           0
# 19                                                 PVT  ...           0
# 20   COMM/    PVT/   PVT/     PVT/      COMM/    CO...  ...           0
# 21                                                 PVT  ...           0
# 22                                         COMM/   PVT  ...           0
# 23                                                COMM  ...           0
# 24                                           COMM/  NA  ...           1
# 25                                                COMM  ...           0
# 26                                                COMM  ...           0
# 27                                                 PVT  ...           0
# 28                                                COMM  ...           0
# 29                                         COMM/  COMM  ...           0
# ..                                                 ...  ...         ...
# 90                                          PVT/   PVT  ...           0
# 91                                                 PVT  ...           0
# 92                                                COMM  ...           0
# 93                                         COMM/  COMM  ...           0
# 94                                                COMM  ...           0
# 95                                          COMM/  PVT  ...           0
# 96                                           PVT/  PVT  ...           0
# 97                                       COMM/    COMM  ...           0
# 98                                          PVT/  COMM  ...           0
# 99                                                COMM  ...           0
# 100                                               COMM  ...           0
# 101                             COMM/    COMM/    COMM  ...           0
# 102                                               COMM  ...           0
# 103                                               COMM  ...           0
# 104                                               COMM  ...           0
# 105                                        COMM/  COMM  ...           0
# 106                                       COMM/   COMM  ...           0
# 107                                      COMM/    COMM  ...           0
# 108                                      COMM/    COMM  ...           0
# 109                               COMM/    COMM/   PVT  ...           0
# 110                                               COMM  ...           0
# 111                                               COMM  ...           0
# 112                                               COMM  ...           0
# 113                                          PVT/ COMM  ...           0
# 114                                        COMM/  COMM  ...           0
# 115                                       COMM/    PVT  ...           0
# 116                                       COMM/   COMM  ...           0
# 117                                 PVT/  COMM/   COMM  ...           0
# 118                                        COMM/   PVT  ...           0
# 119                                                  0  ...           2
#
#     Unnamed: 27      Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0           NaN              NaN         NaN         NaN         NaN
# 1           NaN  PEOPLE INVOLVED         NaN         NaN         NaN
# 2         TOTAL            ADULT         NaN       CHILD         NaN
# 3           NaN                M           F           M           F
# 4            ac               ad          ae          af          ag
# 5             0                6           0           0           0
# 6             0               11           6           0           0
# 7             0               14           5           0           0
# 8            10                7           8           2           1
# 9             1                5           0           0           0
# 10            1               28           0           0           0
# 11            2                2           0           0           0
# 12            0                4           0           0           0
# 13            0                6           0           0           0
# 14            1                9           0           0           0
# 15            1                3           1           0           1
# 16            0               13           7           0           0
# 17            1                1           2           2           3
# 18            1               20           5           0           0
# 19            1                1           0           0           0
# 20            1               12           2           0           0
# 21            2               18           0           0           0
# 22            0               10           1           0           0
# 23            0                5           0           0           0
# 24            2                2           1           0           1
# 25            0                5           0           0           0
# 26            0                4           0           0           0
# 27            1                1           0           0           0
# 28            0                4           0           0           0
# 29            1               13           0           0           0
# ..          ...              ...         ...         ...         ...
# 90            0                3           2           0           8
# 91            0                2           0           0           0
# 92            1                5           0           0           0
# 93            1                2           0           0           0
# 94            0                9          15          12           4
# 95            0                3           1           0           0
# 96            1                3           6           0           0
# 97            0               19           2           2           0
# 98            0                1           2           6           0
# 99            0                3          12           0           0
# 100           0                4           0           0           0
# 101           0                9           1           0           1
# 102           0               10           6           0           0
# 103           0                4           0           0           0
# 104           0                7           2           1           0
# 105           0                6           3           1           0
# 106           0                5           0           0           0
# 107           1                7           0           0           0
# 108           1               25           1           0           0
# 109           0                8           2           0           0
# 110           0               17           0           0           0
# 111           2               50           0           0           0
# 112           0                2           0           0           0
# 113           0               10           0           2           0
# 114           0                6           0           0           0
# 115           2                6           0           0           0
# 116           7               11           2           0           0
# 117           0                5           1           0           2
# 118           0               20           6           0           1
# 119          65              844         193          33          34
#
#     Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0           NaN         NaN         NaN         NaN
# 1           NaN   RTC TYPE          NaN         NaN
# 2         TOTAL         NaN         NaN         NaN
# 3           NaN           F           S           M
# 4            ah          ai          aj          ak
# 5             6           0           1           0
# 6            17           0           1           0
# 7            19           0           1           0
# 8            18           1           0           0
# 9             5           1           0           0
# 10           28           1           0           0
# 11            2           1           0           0
# 12            4           0           1           0
# 13            6           0           1           0
# 14            9           1           0           0
# 15            5           1           0           0
# 16           20           0           1           0
# 17            8           1           0           0
# 18           25           1           0           0
# 19            1           1           0           0
# 20           14           1           0           0
# 21           18           1           0           0
# 22           11           0           0           1
# 23            5           0           1           0
# 24            4           1           0           0
# 25            5           0           1           0
# 26            4           0           0           1
# 27            1           1           0           0
# 28            4           0           1           0
# 29           13           1           0           0
# ..          ...         ...         ...         ...
# 90           13           0           1           0
# 91            2           0           1           0
# 92            5           1           0           0
# 93            2           1           0           0
# 94           40           0           1           0
# 95            4           0           1           0
# 96            9           1           0           0
# 97           23           0           1           0
# 98            9           0           1           0
# 99           15           0           1           0
# 100           4           0           1           0
# 101          11           0           1           0
# 102          16           0           1           0
# 103           4           0           1           0
# 104          10           0           1           0
# 105          10           1           0           0
# 106           5           0           0           1
# 107           7           1           0           0
# 108          26           1           0           0
# 109          10           0           1           0
# 110          17           0           1           0
# 111          50           1           0           0
# 112           2           0           0           1
# 113          12           0           1           0
# 114           6           0           1           0
# 115           6           1           0           0
# 116          13           1           0           0
# 117           8           0           1           0
# 118          27           0           1           0
# 119        1104          42          61          11
#
# [120 rows x 36 columns]

# %%
pd.set_option('max_colwidth', 200)
pd.set_option('max_info_rows', 1000)

# %%
target_len = len(target)
data=pd.concat([target1,target])

# %%
# save this cleaned df to csv
#data.to_csv('cleaned.csv', index=False)

# %%
data
# Out:
#                                          ZONE RS11 OSOGBO Unnamed: 1  \
# 0    2017 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC CRASHES        NaN
# 1                                                     S/N    COMMAND
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4                                                       a          b
# 5                                                       1    RS11.39
# 6                                                       2    RS11.38
# 7                                                       3    RS11.31
# 8                                                       4    RS11.31
# 9                                                       5    RS11.38
# 10                                                      6    RS11.38
# 11                                                      7    RS11.38
# 12                                                      8    RS11.38
# 13                                                      9    RS11.38
# 14                                                     10    RS11.31
# 15                                                     11    RS11.38
# 16                                                     12    RS11.31
# 17                                                     13    RS11.39
# 18                                                     14    RS11.38
# 19                                                     15    RS11.31
# 20                                                     16    RS11.31
# 21                                                     17    RS11.38
# 22                                                     18    RS11.31
# 23                                                     19    RS11.38
# 24                                                     20    RS11.31
# 25                                                     21    RS11.31
# 26                                                     22    RS11.38
# 27                                                     23    RS11.31
# 28                                                     24    RS11.39
# 29                                                     25    RS11.39
# ..                                                    ...        ...
# 122                                                   118    RS11.31
# 123                                                   119    RS11.38
# 124                                                   120    RS11.38
# 125                                                   121    RS11.38
# 126                                                   122    RS11.38
# 127                                                   123    RS11.38
# 128                                                   124    RS11.31
# 129                                                   125    RS11.31
# 130                                                   126    RS11.31
# 131                                                   127    RS11.31
# 132                                                   128    RS11.38
# 133                                                   129    RS11.39
# 134                                                   130    RS11.39
# 135                                                   131    RS11.38
# 136                                                   132    RS11.31
# 137                                                   133    RS11.38
# 138                                                   134    RS11.31
# 139                                                   135    RS11.38
# 140                                                   136    RS11.39
# 141                                                   137    RS11.38
# 142                                                   138    RS11.39
# 143                                                   139    RS11.31
# 144                                                   140    RS11.38
# 145                                                   141    RS11.31
# 146                                                   142    RS11.31
# 147                                                   143    RS11.31
# 148                                    TOTAL FOR THE YEAR        NaN
# 149                                                   NaN        NaN
# 150                                                   NaN        NaN
# 151                                                   NaN        NaN
#
#      Unnamed: 2 Unnamed: 3        Unnamed: 4 Unnamed: 5  \
# 0           NaN        NaN               NaN        NaN
# 1          DATE        DAY  CRASH TIME (HRS)      ROUTE
# 2           NaN        NaN               NaN        NaN
# 3           NaN        NaN               NaN        NaN
# 4             c          c                 d          h
# 5    01/01/2017        SUN               740    IBD-OYO
# 6    01/01/2017        SUN              1326    OYO-OGB
# 7    08/01/2017        SUN              1303    OGB-ILN
# 8    14/01/2017        SAT              1040    OGB-OYO
# 9    18/01/2017        WED               406    OYO-OGB
# 10   20/01/2017        FRI               541    OYO-OGB
# 11   26/01/2017        THU              1111    OYO-OGB
# 12   28/01/2017        SAT              1012    OYO-IBD
# 13   29/01/2017        SUN              1420    OYO-IBD
# 14   30/01/2017        MON               130    OGB-OYO
# 15   04/02/2017        SAT               822    OYO-IBD
# 16   04/02/2017        SAT              1910    OGB-OYO
# 17   07/02/2017        TUE              1545    OYO-IBD
# 18   12/02/2017        SUN              1258    OYO-OGB
# 19   13/02/2017        MON              1810    OGB-OYO
# 20   15/02/2017        WED              1550    OGB-ILN
# 21   16/02/2017        THU                20    OYO-OGB
# 22   20/02/2017        MON              1304    OGB-OYO
# 23   22/02/2017        WED               201    OYO-IBD
# 24   23/02/2017        THU               930    OGB-OYO
# 25   03/03/2017        FRI              2134    OGB-OYO
# 26   04/03/2017        SAT              1211    OYO-OGB
# 27   10/03/2017        FRI              1816    OGB-ILN
# 28   14/03/2017        TUE              1330    IBD-OYO
# 29   14/03/2017        TUE              2205    IBD-OYO
# ..          ...        ...               ...        ...
# 122    05/10/18        FRI              1737    OGB-OYO
# 123    07/10/18        SUN              1030    OYO-IBD
# 124    09/10/18        TUE              0832    OYO-IBD
# 125    09/10/18        TUE              1125    OYO-OGB
# 126    10/10/18        WED              1045    OYO-IBD
# 127    11/10/18        THU              1645    OYO-OGB
# 128    13/10/18        SAT              2025    OGB-ILN
# 129    14/10/18        SUN              1630    OGB-ILN
# 130    17/10/18        WED              0649    OGB-OYO
# 131    17/10/18        WED              1025    OGB-OYO
# 132    18/10/18        THU              1720    OYO-OGB
# 133    25/10/18        THU              1330    OYO-IBD
# 134    08/11/18        THU              1359    OYO-IBD
# 135    10/11/18        SAT              1032    OYO-OGB
# 136    13/11/18        TUE              0630    OGB-ILN
# 137    14/11/18        WED              1431    OYO-OGB
# 138    19/11/18        MON              0835    OGB-OYO
# 139    20/11/18        TUE              1320    OYO-OGB
# 140    24/11/18        SAT              1750    OYO-IBD
# 141    09/12/18        SUN              1020    OYO-IBD
# 142    10/12/18        MON              1250    OYO-IBD
# 143    11/12/18        TUE              0328    OGB-OYO
# 144    11/12/18        TUE              1620    OYO-IBD
# 145    11/12/18        TUE              2124    OGB-OYO
# 146    16/12/18        SUN              1310    OGB-OYO
# 147    30/12/18        SUN              1140    OGB-OYO
# 148         NaN        NaN               NaN        NaN
# 149         NaN        NaN               NaN        NaN
# 150         NaN        NaN               NaN        NaN
# 151         NaN        NaN               NaN        NaN
#
#                              Unnamed: 6      Unnamed: 7  \
# 0                                   NaN             NaN
# 1                              LOCATION  VEHICLE NUMBER
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                     i               j
# 5                                  TOSE               1
# 6                            KM8-AGBOYE               2
# 7                             KM5-TAKIE               2
# 8                          15KM-ODO OBA               1
# 9                          KM11-LAWYER                1
# 10                   KM25-IPEBA VILLAGE               3
# 11                         KM18-ALAIDAN               1
# 12                           KM2-OLIVET               2
# 13                          KM12-JOBELE               2
# 14                      KM3-AJAIYA AREA               1
# 15                         KM10-ELEKARA               2
# 16                       KM6-AGRIC AREA               2
# 17                     DEEPER LIFE JCTN               2
# 18                   KM17-OWEYO VILLAGE               3
# 19                   KM1.5-HIGH  SCHOOL               1
# 20                              KM6-GTB               7
# 21                  KM22-ALABON VILLAGE               1
# 22                            FRSC BASE               2
# 23                          KM12-JOBELE               1
# 24                         KM20HIGH SCH               2
# 25                          KM6-ILE ABU               1
# 26                         KM15-IJAWAYA               1
# 27                         KM8-OJA WASO               1
# 28                        ISAJOG FUEL/S               1
# 29                AKINYELE UNDER BRIDGE               2
# ..                                  ...             ...
# 122        KM10-ILE-ABU VILLAGE/ODO-OBA               3
# 123                         KM18-FIDITI               1
# 124                         KM11-JOBELE               1
# 125                         KM10-AGBOYE               1
# 126                    KM1-ILORA BRIDGE               2
# 127              KM1-SCH OF SURVEY AREA               2
# 128                    KM1-ODO ORU JCTN               1
# 129        KM1-RANDAH R/A BY BOWEN HOSP               1
# 130                 KM8- AJE IYA FUEL/S               2
# 131                      KM7.5 -ARINKIN               1
# 132               KM12.3-AGBOYE VILLAGE               1
# 133  KM16-IROKO AFTER KOLADAISI VERSITY               1
# 134                               IROKO               2
# 135                KM16-IJAWAYA VILLAGE               1
# 136               KM10-MECHANIC VILLAGE               2
# 137                   KM11.5-ABA LAWYER               2
# 138                KM8.5-SEKONA VILLAGE               3
# 139                     KM2-CUSTOM AREA               1
# 140                    5KM 4RM OJOO-RCC               1
# 141                         KM17-FIDITI               1
# 142  10KM 4RM IBD-AKINYELE UNDER BRIDGE               2
# 143              KM15-OOLO COM GRAM SCH               2
# 144                    KM7-ILORA BRIDGE               2
# 145            KM17-ASANI ELEGA VILLAGE               1
# 146                 KM4.5-HIGH SCH JCTN               1
# 147                       KM5-FRSC BASE               2
# 148                                 NaN             236
# 149                                 NaN             NaN
# 150                                 NaN             NaN
# 151                                 NaN             NaN
#
#                                                                  Unnamed: 8  \
# 0                                                                       NaN
# 1                                                            VEHICLE NUMBER
# 2                                                                       NaN
# 3                                                                       NaN
# 4                                                                         j
# 5                                                                  MUS238DA
# 6                                                     KSF384BR/    GMD202XA
# 7                                                      KWL549XA/   BDS212XA
# 8                                                                  KRD180XB
# 9                                                                  LSR711BV
# 10                                        OKA875ZU/    KNH387XA/   SMK401XA
# 11                                                                 RAN248XA
# 12                                                 FKJ310XA/       OY6985AA
# 13                                                 NPF1216/         FN99EKY
# 14                                                                 DKA473ZU
# 15                                                  TRN359ZG/      JJJ102CY
# 16                                                   KJA775XJ/     KJA978XK
# 17                                               SUL372XA/         EPE222DJ
# 18                                           NA/      BDG229XQ/    DUT285XA
# 19                                                                      NaN
# 20   APP995XP/  LND517AU/  SMK468CW/   RSD296AAA/  QW944EKY/  YNF686QA/  NA
# 21                                                                 AA602MHT
# 22                                                    AGL247XP/    AJ394KNH
# 23                                                                 XA380KNK
# 24                                                            EKY321QB/  NA
# 25                                                                 XC321MNY
# 26                                                                 RBC662XP
# 27                                                                 KSF221DV
# 28                                                         EPE885XG/
# 29                                                     SNN28XA/    JJJ804XQ
# ..                                                                      ...
# 122                    KJM99XA/          EPE872EU/                 BDU567XA
# 123                                                                AFN734XA
# 124                                                                AGL419XN
# 125                                                                RMY228XA
# 126                                                 EKY892DK/            NA
# 127                                              LND934XV/         OY7550YC
# 128                                                                AAW480AA
# 129                                                                TDE315AA
# 130                                                   XB397KKY/    KTU220XC
# 131                                                                     NaN
# 132                                                                MUS490BP
# 133                                                                XB218BBJ
# 134                                                 EPE348AP/      LSR411XJ
# 135                                                                WDL674XA
# 136                                                  GZW45XA/      XC324KTC
# 137                                                   NSD309XT/    KTU455XM
# 138                               GGE869FK/       TTN731QE/        KEY992DS
# 139                                                                YH506EPE
# 140                                                                 OY19A41
# 141                                                                 APP47DR
# 142                                                   BKD361XA/    PMD208XA
# 143                                                       NA/      AME746XA
# 144                                                EKY166XV/       YYY488XA
# 145                                                                ARP716XA
# 146                                                                 KWL62ZA
# 147                                             SMK406XQ/          LRN952NK
# 148                                                                       0
# 149                                                                     NaN
# 150                                                                     NaN
# 151                                                                     NaN
#
#                                                    Unnamed: 9  ...  \
# 0                                                         NaN  ...
# 1                                               VEHICLE CLASS  ...
# 2                                                         NaN  ...
# 3                                                         NaN  ...
# 4                                                           k  ...
# 5                                                         PVT  ...
# 6                                               PVT/     COMM  ...
# 7                                                COMM/   COMM  ...
# 8                                                        COMM  ...
# 9                                                         PVT  ...
# 10                                         COMM/  COMM/  COMM  ...
# 11                                                       COMM  ...
# 12                                               COMM/   COMM  ...
# 13                                              GOVT/     PVT  ...
# 14                                                       COMM  ...
# 15                                                COMM/   PVT  ...
# 16                                                COMM/  COMM  ...
# 17                                                COMM/   PVT  ...
# 18                                        COMM/   COMM/  COMM  ...
# 19                                                        PVT  ...
# 20   COMM/    PVT/   PVT/     PVT/      COMM/    COMM/   COMM  ...
# 21                                                        PVT  ...
# 22                                                COMM/   PVT  ...
# 23                                                       COMM  ...
# 24                                                  COMM/  NA  ...
# 25                                                       COMM  ...
# 26                                                       COMM  ...
# 27                                                        PVT  ...
# 28                                                       COMM  ...
# 29                                                COMM/  COMM  ...
# ..                                                        ...  ...
# 122                                       COMM/   PVT/   COMM  ...
# 123                                                      COMM  ...
# 124                                                      COMM  ...
# 125                                                      COMM  ...
# 126                                               COMM/  COMM  ...
# 127                                              COMM/    PVT  ...
# 128                                                       PVT  ...
# 129                                                       PVT  ...
# 130                                              COMM/   COMM  ...
# 131                                              COMM/   COMM  ...
# 132                                                       PVT  ...
# 133                                                      COMM  ...
# 134                                              PVT/     PVT  ...
# 135                                                      COMM  ...
# 136                                               COMM/  COMM  ...
# 137                                               COMM/  COMM  ...
# 138                                 PVT/       COMM/      PVT  ...
# 139                                                      COMM  ...
# 140                                                       PVT  ...
# 141                                                       PVT  ...
# 142                                               COMM/  COMM  ...
# 143                                               COMM/  COMM  ...
# 144                                               COMM/  COMM  ...
# 145                                               COMM/  COMM  ...
# 146                                                      COMM  ...
# 147                                              COMM/    PVT  ...
# 148                                                         0  ...
# 149                                                       NaN  ...
# 150                                                       NaN  ...
# 151                                                       NaN  ...
#
#     Unnamed: 26 Unnamed: 27      Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0           NaN         NaN              NaN         NaN         NaN
# 1           NaN         NaN  PEOPLE INVOLVED         NaN         NaN
# 2           NaN       TOTAL            ADULT         NaN       CHILD
# 3             F         NaN                M           F           M
# 4            ab          ac               ad          ae          af
# 5             0           0                6           0           0
# 6             0           0               11           6           0
# 7             0           0               14           5           0
# 8             1          10                7           8           2
# 9             0           1                5           0           0
# 10            0           1               28           0           0
# 11            0           2                2           0           0
# 12            0           0                4           0           0
# 13            0           0                6           0           0
# 14            0           1                9           0           0
# 15            0           1                3           1           0
# 16            0           0               13           7           0
# 17            0           1                1           2           2
# 18            0           1               20           5           0
# 19            0           1                1           0           0
# 20            0           1               12           2           0
# 21            0           2               18           0           0
# 22            0           0               10           1           0
# 23            0           0                5           0           0
# 24            1           2                2           1           0
# 25            0           0                5           0           0
# 26            0           0                4           0           0
# 27            0           1                1           0           0
# 28            0           0                4           0           0
# 29            0           1               13           0           0
# ..          ...         ...              ...         ...         ...
# 122           0           0                9           2           0
# 123           0           0                8           6           1
# 124           0           1                8           5           0
# 125           0           0               12           1           0
# 126           0           0                3           1           0
# 127           0           1                2           0           0
# 128           0           1                3           1           0
# 129           0           1                5           0           0
# 130           0           8                6           3           3
# 131           0           2                4           0           0
# 132           1           2                1           1           0
# 133           0           2                8           9           0
# 134           0           0                2           0           0
# 135           0           1                3           0           0
# 136           0           6               22           0           0
# 137           0           3                3           3           0
# 138           0           0                6           0           0
# 139           0           0               10           8           0
# 140           0           1                2           0           0
# 141           0           3                7           0           0
# 142           0           4                7           0           0
# 143           0           0               10           3           0
# 144           0           2                7           1           7
# 145           0           0                2           6           0
# 146           0           0                3           0           0
# 147           0           0                8           6           0
# 148           3         115              947         255          25
# 149         NaN         NaN              NaN         NaN         NaN
# 150         NaN         NaN              NaN         NaN         NaN
# 151         NaN         NaN              NaN         NaN         NaN
#
#     Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN   RTC TYPE          NaN         NaN
# 2           NaN       TOTAL         NaN         NaN         NaN
# 3             F         NaN           F           S           M
# 4            ag          ah          ai          aj          ak
# 5             0           6           0           1           0
# 6             0          17           0           1           0
# 7             0          19           0           1           0
# 8             1          18           1           0           0
# 9             0           5           1           0           0
# 10            0          28           1           0           0
# 11            0           2           1           0           0
# 12            0           4           0           1           0
# 13            0           6           0           1           0
# 14            0           9           1           0           0
# 15            1           5           1           0           0
# 16            0          20           0           1           0
# 17            3           8           1           0           0
# 18            0          25           1           0           0
# 19            0           1           1           0           0
# 20            0          14           1           0           0
# 21            0          18           1           0           0
# 22            0          11           0           0           1
# 23            0           5           0           1           0
# 24            1           4           1           0           0
# 25            0           5           0           1           0
# 26            0           4           0           0           1
# 27            0           1           1           0           0
# 28            0           4           0           1           0
# 29            0          13           1           0           0
# ..          ...         ...         ...         ...         ...
# 122           0          11           0           1           0
# 123           1          16           0           1           0
# 124           0          13           1           0           0
# 125           0          13           0           1           0
# 126           0           4           0           1           0
# 127           0           2           1           0           0
# 128           0           4           1           0           0
# 129           0           5           1           0           0
# 130           0          12           1           0           0
# 131           0           4           1           0           0
# 132           1           3           1           0           0
# 133           0          17           1           0           0
# 134           0           2           0           1           0
# 135           0           3           1           0           0
# 136           0          22           1           0           0
# 137           0           6           1           0           0
# 138           0           6           0           1           0
# 139           0          18           0           1           0
# 140           0           2           1           0           0
# 141           0           7           1           0           0
# 142           0           7           1           0           0
# 143           0          13           0           1           0
# 144           2          17           1           0           0
# 145           0           8           0           1           0
# 146           0           3           0           0           1
# 147           0          14           0           0           1
# 148          21        1248          62          74           7
# 149         NaN         NaN         NaN         NaN         NaN
# 150         NaN         NaN         NaN         NaN         NaN
# 151         NaN         NaN         NaN         NaN         NaN
#
# [272 rows x 36 columns]

# %%
# let's print these 180 `nan` containing rows 
data[data.isnull().any(axis=1)].head()
# Out:
#                                        ZONE RS11 OSOGBO Unnamed: 1  \
# 0  2017 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC CRASHES        NaN
# 1                                                   S/N    COMMAND
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 5                                                     1    RS11.39
#
#    Unnamed: 2 Unnamed: 3        Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN               NaN        NaN        NaN
# 1        DATE        DAY  CRASH TIME (HRS)      ROUTE   LOCATION
# 2         NaN        NaN               NaN        NaN        NaN
# 3         NaN        NaN               NaN        NaN        NaN
# 5  01/01/2017        SUN               740    IBD-OYO       TOSE
#
#        Unnamed: 7      Unnamed: 8     Unnamed: 9  ... Unnamed: 26 Unnamed: 27  \
# 0             NaN             NaN            NaN  ...         NaN         NaN
# 1  VEHICLE NUMBER  VEHICLE NUMBER  VEHICLE CLASS  ...         NaN         NaN
# 2             NaN             NaN            NaN  ...         NaN       TOTAL
# 3             NaN             NaN            NaN  ...           F         NaN
# 5               1        MUS238DA            PVT  ...           0           0
#
#        Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0              NaN         NaN         NaN         NaN         NaN
# 1  PEOPLE INVOLVED         NaN         NaN         NaN         NaN
# 2            ADULT         NaN       CHILD         NaN       TOTAL
# 3                M           F           M           F         NaN
# 5                6           0           0           0           6
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0         NaN         NaN         NaN
# 1   RTC TYPE          NaN         NaN
# 2         NaN         NaN         NaN
# 3           F           S           M
# 5           0           1           0
#
# [5 rows x 36 columns]

# %%
df_cc = data.loc[:,'Unnamed: 18':]

# %%
made=data.drop(df_cc,axis=1)

# %%
made=made.drop(['Unnamed: 12','Unnamed: 14','Unnamed: 15','Unnamed: 16'], axis=1)

# %%
# let's print these 180 `nan` containing rows 
made[made.isnull().any(axis=1)].head()
# Out:
#                                         ZONE RS11 OSOGBO Unnamed: 1  \
# 0   2018 IBADAN-OYO-OGBOMOSO-ILORIN ROAD TRAFFIC CRASHES        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 37                                                    33    RS11.31
# 91                                                    87    RS11.31
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5                  Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN                         NaN
# 2         NaN        NaN        NaN        NaN                         NaN
# 3         NaN        NaN        NaN        NaN                         NaN
# 37   19/03/18        MON       0640    OGB-OYO            KM1.7-ARINKINKIN
# 91   06/08/18        MON       0600    OGB-OYO  KM5-HIGH SCH AREA BY IBEDC
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 13  \
# 0         NaN        NaN        NaN         NaN         NaN         NaN
# 2         NaN        NaN        NaN         NaN         NaN         NaN
# 3         NaN        NaN        NaN         NaN         NaN         NaN
# 37          1        NaN       COMM         TRL       VOLVO   VOLVO TRL
# 91          1        NaN       COMM         TRL         DAF     DAF TRL
#
#    Unnamed: 17
# 0          NaN
# 2          NaN
# 3          NaN
# 37         NJR
# 91     NJA,LOC

# %%
# for now remove all nan rows as they are just 0.6%
made = made[~made.isnull().any(axis=1)]
made.reset_index(inplace=True)
made.drop('index', inplace=True, axis=1)
made.shape
# Out:
# (255, 14)

# %%
made
# Out:
#     ZONE RS11 OSOGBO Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0                S/N    COMMAND       DATE        DAY  CRASH TIME (HRS)
# 1                  a          b          c          c                 d
# 2                  1    RS11.31   01/01/18        MON              0855
# 3                  2    RS11.39   03/01/18        WED              1040
# 4                  3    RS11.31   03/01/18        WED              1121
# 5                  4    RS11.38   04/01/18        THU              1425
# 6                  5    RS11.38   06/01/18        SAT              1650
# 7                  6    RS11.31   07/01/18        SUN              0325
# 8                  7    RS11.39   10/01/18        WED              0740
# 9                  8    RS11.39   10/01/18        WED              0930
# 10                 9    RS11.39   12/01/18        FRI              1150
# 11                10    RS11.39   15/01/18        MON              1940
# 12                11    RS11.31   17/01/18        WED              1625
# 13                12    RS11.39   22/01/18        MON              0600
# 14                13    RS11.38   24/01/18        WED              1630
# 15                14    RS11.31   27/01/18        SAT              1705
# 16                15    RS11.38   28/01/18        SUN              0752
# 17                16    RS11.38   30/01/18        TUE              0900
# 18                17    RS11.31   08/02/18        THU              0910
# 19                18    RS11.38   09/02/18        FRI              0355
# 20                19    RS11.38   14/02/18        WED              1255
# 21                20    RS11.31   18/02/18        SUN              1145
# 22                21    RS11.31   18/02/18        SUN              1730
# 23                22    RS11.31   20/02/18        TUE              1830
# 24                23    RS11.31   20/02/18        TUE              2330
# 25                24    RS11.31   21/02/18        WED              1032
# 26                25    RS11.38   24/02/18        SAT              0935
# 27                26    RS11.38   04/03/18        SUN              1730
# 28                27    RS11.38   10/03/18        SAT              1617
# 29                28    RS11.31   10/03/18        SAT              2000
# ..               ...        ...        ...        ...               ...
# 225               83    RS11.38   14/08/17        MON              1228
# 226               84    RS11.38   14/08/17        MON              2059
# 227               86    RS11.31   18/08/17        FRI              1630
# 228               87    RS11.38   23/08/17        WED              0730
# 229               89    RS11.39   30/08/17        WED              0950
# 230               90    RS11.38   30/08/17        WED              1043
# 231               91    RS11.39   02/09/17        SAT              1445
# 232               92    RS11.31   05/09/17        TUE              0900
# 233               93    RS11.31   17/09/17        SUN              0410
# 234               94    RS11.39   24/09/17        SUN              0900
# 235               95    RS11.38   25/09/17        MON              1330
# 236               96    RS11.38   04/10/17        WED              2100
# 237               97    RS11.38   10/10/17        TUE              0610
# 238               98    RS11.38   10/10/17        TUE              1505
# 239               99    RS11.38   17/10/17        TUE              1146
# 240              100    RS11.38   18/10/17        WED              1255
# 241              101    RS11.38   02/11/17        THU              1415
# 242              102    RS11.31   07/11/17        TUE              1020
# 243              103    RS11.38   27/11/17        MON              1406
# 244              104    RS11.31   29/11/17        WED              0428
# 245              105    RS11.38   15/12/17        FRI              0944
# 246              106    RS11.38   18/12/17        MON              1015
# 247              107    RS11.39   19/12/17        TUE              0445
# 248              108    RS11.38   20/12/17        WED              0845
# 249              109    RS11.38   21/12/17        THU              1340
# 250              110    RS11.31   22/12/17        FRI              2040
# 251              111    RS11.31   23/12/17        SAT              1320
# 252              112    RS11.39   26/12/17        TUE              0720
# 253              113    RS11.31   28/12/17        THU              1300
# 254              114    RS11.38   29/12/17        FRI              1510
#
#     Unnamed: 5                   Unnamed: 6      Unnamed: 7  \
# 0        ROUTE                     LOCATION  VEHICLE NUMBER
# 1            h                            i               j
# 2      OGB-OYO                   KM7-IBAPON               2
# 3      OYO-IBD      KM5 4RM IBD-MOBILE AREA               3
# 4      OGB-OYO                   KM7-IBAPON               1
# 5      OYO-OGB       KM2-ODO ASHIPA VILLAGE               3
# 6      OYO-OGB     KM3-FED LOW COST HOUSING               2
# 7      OGB-OYO                    KM5-AGRIC               1
# 8      IBD-OYO         KM7-DEPEER LIFE AREA               1
# 9      IBD-OYO               KM5-TOSHE AREA               2
# 10     IBD-OYO          OLD RD BY BANK JCTN               2
# 11     OYO-IBD        4KM 4RM IBD-NNPC JCTN               1
# 12     OGB-ILN           KM10-AROJE EXPRESS               2
# 13     OYO-IBD         10KM 4RM IBD-ABE ODO               7
# 14     OYO-OGB          KM21-BUSARI VILLAGE               2
# 15     OGB-OYO          KM12-ISANLA VILLAGE               2
# 16     OYO-OGB             KM4-CUSTOMS AREA               2
# 17     OYO-OGB              KM1-DURBAR AREA               2
# 18     OGB-OYO                   KM9-SEKONA               1
# 19     OYO-OGB                 KM17-ONIGARI               2
# 20     OYO-OGB         KM10.3-IDODE VILLAGE               2
# 21     OGB-OYO               KM5-ARINKINKIN               1
# 22     OGB-OYO                   KM12-ELEGA               2
# 23     OGB-ILN                  KM19-ABDUKA               1
# 24     OGB-ILN            KM8-AROJE VILLAGE               1
# 25     OGB-ILN                 KM19.5-GBEDE               1
# 26     OYO-OGB              KM2-CUSTOM AREA               1
# 27     OYO-OGB            KM20-ALAFARA VILL               2
# 28     OYO-IBD                 KM29-MOTUNDE               1
# 29     OGB-OYO                    KM13-OLOO               1
# ..         ...                          ...             ...
# 225    OYO-OGB                   KM3-ORIAWO               1
# 226    OYO-OGB                 KM2-AWE JCTN               2
# 227    OGB-OYO          KM6-ILE ABU, SEKONA               2
# 228    OYO-IBD                  KM18-FIDITI               1
# 229    IBD-OYO        KM3- OPP RCC, IDI OSE               2
# 230    OYO-IBD                  KM15-JOBELE               1
# 231    IBD-OYO         KM5-POWER LINE, LABI               2
# 232    OGB-ILN  3KM 4RM LAUTH-AROJE VILLAGE               2
# 233    OGB-OYO           KM 3-HIGH SCH JUCT               2
# 234    OYO-IBD        6KM FROM IBD-AKINYELE               2
# 235    OYO-OGB                 KM17-ALAGBON               1
# 236    OYO-OGB                  KM6-OFAMETA               1
# 237    OYO-OGB              KM6-BODE THOMAS               3
# 238    OYO-IBD                  KM14-FIDITI               1
# 239    OYO-OGB              KM2-ORIAWO JCTN               1
# 240    OYO-OGB            KM13.3-ABA LAWYER               1
# 241    OYO-OGB             KM13-CUSTOM AREA               2
# 242    OGB-OYO         KM21-IDI EMI VILLAGE               2
# 243    OYO-OGB         KM12-ALAIDAN VILLAGE               2
# 244    OGB-OYO          KM15-ALAYIN VILLAGE               2
# 245    OYO-OGB          KM33-LAWYER VILLAGE               3
# 246    OYO-OGB          KM2-PACIFIC ACADEMY               1
# 247    OYO-IBD      5KM 4RM IBD-DEEPER LIFE               1
# 248    OYO-IBD            KM7-OMOTUNDE AREA               1
# 249    OYO-OGB              KM17-ABA LAWYER               2
# 250    OGB-OYO          KM12-IBAPON VILLAGE               2
# 251    OGB-OYO     KM2.5-AJE IYA FUEL STATE               2
# 252    IBD-OYO       KM20-AKINYELE TRL PARK               2
# 253    OGB-OYO           KM20-IPEBA VILLAGE               3
# 254    OYO-OGB           KM40-OWOYO VILLAGE               2
#
#                                                                                                       Unnamed: 8  \
# 0                                                                                                 VEHICLE NUMBER
# 1                                                                                                              j
# 2                                                                                       KJA166XM/       WDL522XA
# 3                                                                               KTN207XA/ BDU341XA.     EKY309ZF
# 4                                                                                                       XA365KMB
# 5                                                                                      KSF87QX/     XB624KMA/ NA
# 6                                                                                          DKA129XF/    AAA146FB
# 7                                                                                                       BDU660ZQ
# 8                                                                                                       BDJ430ZQ
# 9                                                                                           LND843XA/         NA
# 10                                                                                          AG801RUM/   KTU429EZ
# 11                                                                                                      KSF591XG
# 12                                                                                         AA471BDA/    LND554ER
# 13   KRD804BG/         EPE997DB/        LSR30XA/       XW962MAN/ GML85XY/       NA/                      MGR16XA
# 14                                                                                       XE455PFA/      LKJ790XU
# 15                                                                                        JJJ318XR/     XB286RLG
# 16                                                                                    KNK153XA/         BDG722QH
# 17                                                                                    AG995FUF/         DTN711QC
# 18                                                                                                       FFA72BW
# 19                                                                           NA/                        LEM563XA
# 20                                                                                        JJJ732XF/     LGB210XA
# 21                                                                                                         UNREG
# 22                                                                                       MUS700XV/      KNR396XA
# 23                                                                                                      XB277BDA
# 24                                                                                                       EPE46QB
# 25                                                                                                      MNA442XV
# 26                                                                                                      KJA570XW
# 27                                                                                       YAB937YJ/       KTG10XA
# 28                                                                                                      YYY891XA
# 29                                                                                                      GML929XA
# ..                                                                                                           ...
# 225                                                                                                     FST347XK
# 226                                                                                              YYY942XA/    NA
# 227                                                                           NA/                       LSD471DY
# 228                                                                                                       KTU874
# 229                                                                                            KEH630QC/      NA
# 230                                                                                                     EKY824XD
# 231                                                                                  KJA307BF/          AKD755DM
# 232                                                                                        SEY211AA/    OY6865RS
# 233                                                                                     AA284FFE/       SUL444XA
# 234                                                                                        LSD817ER/    BDU714XA
# 235                                                                                                     LRN651XA
# 236                                                                                                     XG145MKA
# 237                                                                          BNZ887CA/    XA503KUR/     NRR915YQ
# 238                                                                                                     BDS193XA
# 239                                                                                                     XA200GWD
# 240                                                                                                     LEM540XA
# 241                                                                                        ARP705XA/    FMT731QC
# 242                                                                                         KRA174XA/    KWN65ZA
# 243                                                                                       KMC02YQ/      GWL161YJ
# 244                                                                                    NA/               JAL917X
# 245                                                                            KNH373XA/     EPE142XQ/  LSR813DZ
# 246                                                                                                     NSR728ZD
# 247                                                                                                      KTN79XA
# 248                                                                                                     XA170AKD
# 249                                                                                           LSD365AC/ MUM730XA
# 250                                                                                         AKD502XN/   LEM573XA
# 251                                                                                     FKJ289XC/       KRD183EY
# 252                                                                                          FTA668XA/        NA
# 253                                                                            APP321CF/     KRD362XM/  EPE194XQ
# 254                                                                                        MKA292XH/    LSR861EL
#
#                                                           Unnamed: 9  \
# 0                                                      VEHICLE CLASS
# 1                                                                  k
# 2                                                       COMM/   COMM
# 3                                                    COMM/COMM/ COMM
# 4                                                               COMM
# 5                                              COMM/    COMM/   COMM
# 6                                                        COMM/   PVT
# 7                                                                PVT
# 8                                                               COMM
# 9                                                      COMM/    GOVT
# 10                                                        PVT/   PVT
# 11                                                              COMM
# 12                                                        PVT/   PVT
# 13   PVT/    PVT/    COMM/    COMM/       COMM/      COMM/      COMM
# 14                                                       COMM/  COMM
# 15                                                       COMM/  COMM
# 16                                                     COMM/    COMM
# 17                                                 PVT/         COMM
# 18                                                               PVT
# 19                                                      COMM/   COMM
# 20                                                       COMM/  COMM
# 21                                                              COMM
# 22                                                       COMM/  COMM
# 23                                                              COMM
# 24                                                               PVT
# 25                                                              COMM
# 26                                                              COMM
# 27                                                       COMM/  COMM
# 28                                                              COMM
# 29                                                              COMM
# ..                                                               ...
# 225                                                             COMM
# 226                                                      COMM/  COMM
# 227                                                       PVT/   PVT
# 228                                                              PVT
# 229                                                      COMM/  COMM
# 230                                                             COMM
# 231                                                       COMM/  PVT
# 232                                                        PVT/  PVT
# 233                                                    COMM/    COMM
# 234                                                       PVT/  COMM
# 235                                                             COMM
# 236                                                             COMM
# 237                                           COMM/    COMM/    COMM
# 238                                                             COMM
# 239                                                             COMM
# 240                                                             COMM
# 241                                                      COMM/  COMM
# 242                                                     COMM/   COMM
# 243                                                    COMM/    COMM
# 244                                                    COMM/    COMM
# 245                                             COMM/    COMM/   PVT
# 246                                                             COMM
# 247                                                             COMM
# 248                                                             COMM
# 249                                                        PVT/ COMM
# 250                                                      COMM/  COMM
# 251                                                     COMM/    PVT
# 252                                                     COMM/   COMM
# 253                                               PVT/  COMM/   COMM
# 254                                                      COMM/   PVT
#
#                                                     Unnamed: 10  \
# 0                                              VEHICLE CATEGORY
# 1                                                             l
# 2                                                 TNK/      TRK
# 3                                          TRL/    BUS/     BUS
# 4                                                          P.UP
# 5                                             TNK/   P.UP/  VAN
# 6                                                  TNK/     CAR
# 7                                                           BUS
# 8                                                           CAR
# 9                                               TNK/        BUS
# 10                                                    CAR/  CAR
# 11                                                          BUS
# 12                                               P.UP/      SUV
# 13   CAR/    BUS/     CAR/      TRL/       TRK/      TRL/   TRL
# 14                                                  BUS/    TNK
# 15                                                  BUS/    BUS
# 16                                                   TNK/    MC
# 17                                                   CAR/    MC
# 18                                                          CAR
# 19                                                  TNK/    BUS
# 20                                                  BUS/    BUS
# 21                                                           MC
# 22                                                   BUS/   BUS
# 23                                                         P.UP
# 24                                                          TRK
# 25                                                          TRK
# 26                                                          BUS
# 27                                                   TNK/   TRL
# 28                                                          BUS
# 29                                                         P.UP
# ..                                                          ...
# 225                                                         TNK
# 226                                                    BUS/  MC
# 227                                                   CAR/  CAR
# 228                                                         SUV
# 229                                                  MC/    TRL
# 230                                                         BUS
# 231                                              TNK/       SUV
# 232                                                   BUS/   MC
# 233                                                  TRK/   BUS
# 234                                               CAR/      TRK
# 235                                                         BUS
# 236                                                        P.UP
# 237                                      TNK/   TRL/        BUS
# 238                                                         BUS
# 239                                                         TRK
# 240                                                         BUS
# 241                                                   BUS/   MC
# 242                                                 TNK/    TNK
# 243                                                  TRK/   TRK
# 244                                                TNK/     BUS
# 245                                           TRK/  TRK/    CAR
# 246                                                         TRK
# 247                                                         TRL
# 248                                                         TRK
# 249                                                   CAR/  CAR
# 250                                                  TRK/   TRK
# 251                                                 TRL/    CAR
# 252                                              BUS/       TRL
# 253                                         BUS/    TRK/    TRL
# 254                                                  TRK/   BUS
#
#                                                                                           Unnamed: 11  \
# 0                                                                                        VEHICLE MAKE
# 1                                                                                                   m
# 2                                                                                  DAF/           DAF
# 3                                                                        IVECO/    TOYOTA/     TOYOTA
# 4                                                                                                MIT.
# 5                                                                 MACK/          MAZDA/       BEDFORD
# 6                                                                                 TAFAWA/      TOYOTA
# 7                                                                                                FORD
# 8                                                                                             V.WAGON
# 9                                                                            MACK/             TOYOTA
# 10                                                                              HYUNDAI/      V.WAGON
# 11                                                                                             TOYOTA
# 12                                                                           DATSUN/           TOYOTA
# 13   HYUNDI/    TOYOTA/          NISSAN/          M.DIESEL/       IVECO/         NA/             MACK
# 14                                                                                 MAZDA/       IVECO
# 15                                                                                TOYOTA/      TOYOTA
# 16                                                                         IVECO/               BAJAJ
# 17                                                                                  MAZDA/      BAJAJ
# 18                                                                                             M.BENZ
# 19                                                                       MACK/                 TOYOTA
# 20                                                                                 MAZDA/       MAZDA
# 21                                                                                             BAJAJ
# 22                                                                                TOYOTA/      TOYOTA
# 23                                                                                               MIT.
# 24                                                                                              IVECO
# 25                                                                                              IVECO
# 26                                                                                             SUZUKI
# 27                                                                    DAF/                        DAF
# 28                                                                                              MAZDA
# 29                                                                                               MIT.
# ..                                                                                                ...
# 225                                                                                              EURO
# 226                                                                                     MAZDA/  BAJAJ
# 227                                                                                   V.WAGON/    PGT
# 228                                                                                            TOYOTA
# 229                                                                        BAJAJ/                  NA
# 230                                                                                            TOYOTA
# 231                                                                                 IVECO/     NISSAN
# 232                                                                             V.WAGON/     JINCHENG
# 233                                                                             M.BENZ/        TOYOTA
# 234                                                                                    M.BENZ/    DAF
# 235                                                                                            TOYOTA
# 236                                                                                            NISSAN
# 237                                                    DAF/                DAF/                TOYOTA
# 238                                                                                             MAZDA
# 239                                                                                            M.BENZ
# 240                                                                                              FORD
# 241                                                                                    FORD/   BAJAJA
# 242                                                                       DAF/                    DAF
# 243                                                                                HOWO/         HOWO
# 244                                                                      DAF/                  TOYOTA
# 245                                                               M.DIESEL/       IVECO/       TOYOTA
# 246                                                                                               DAF
# 247                                                                                             IVECO
# 248                                                                                               DAF
# 249                                                                                   TOYOTA/    FORD
# 250                                                                                M.DIESEL/    VOLVO
# 251                                                                          IVECO/              MIT.
# 252                                                                           TOYOTA/              NA
# 253                                                                     TOYOTA/    SCANNA/      VOLVO
# 254                                                                    DAF/                    TOYOTA
#
#                                                                                                                                                                                                  Unnamed: 13  \
# 0                                                                                                                                                                                               VEHICLE TYPE
# 1                                                                                                                                                                                                          o
# 2                                                                                                                                                        DAF 95X TNK/                            DAF 95X TRK
# 3                                                                                                                                        IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 4                                                                                                                                                                                                MIT. CANTER
# 5                                                                                                                    MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 6                                                                                                                                                                     TAFAWA 418 TNK/              TYT CAMRY
# 7                                                                                                                                                                                                FORD GALAXY
# 8                                                                                                                                                                                               V.WAGON GULF
# 9                                                                                                                                                    MACK TNK/                                   TYT COASTER
# 10                                                                                                                                                                    HYUNDAI LANTRA/           V.WAGON GULF
# 11                                                                                                                                                                                                 TYT HIACE
# 12                                                                                                                                                              DATSUN P.UP/                      TYT TUNDRA
# 13   HYUNDAI SONATA/         TYT PICNIC/                           NISSAN MICRA/                 M.DIESEL TRL/                                          IVECO TRL/                                   NA/ ...
# 14                                                                                                                                                                   MAZDA E2000/                  IVECO TNK
# 15                                                                                                                                                                            TYT SIENNA/          TYT HIACE
# 16                                                                                                                                                           IVECO TNK/                          BAJAJ BOXER
# 17                                                                                                                                                          MAZDA 626/                           BAJAJ BOXER
# 18                                                                                                                                                                                              M.BENZ C240
# 19                                                                                                                                                         MACK TNK/                               TYT HIACE
# 20                                                                                                                                                          MAZDA E2000/                         MAZDA E2000
# 21                                                                                                                                                                                               BAJAJ BOXER
# 22                                                                                                                                                        TYT HIACE/                               TYT HIACE
# 23                                                                                                                                                                                               MIT. CANTER
# 24                                                                                                                                                                                                IVECO  TRK
# 25                                                                                                                                                                                                IVECO  TRK
# 26                                                                                                                                                                                            SUZUKI MIDIBUS
# 27                                                                                                                                                          DAF TNK/                                 DAF TRL
# 28                                                                                                                                                                                               MAZDA E2000
# 29                                                                                                                                                                                               MIT. CANTER
# ..                                                                                                                                                                                                       ...
# 225                                                                                                                                                                                            EURO STAR TNK
# 226                                                                                                                                                                            MAZDA E2000/      BAJAJ BOXER
# 227                                                                                                                                                                 V.WAGON GULF/                    PGT 206
# 228                                                                                                                                                                                                 TYT RAV4
# 229                                                                                                                                                               BAJAJ BOXER/                 HIT & RUN TRL
# 230                                                                                                                                                                                                TYT HIACE
# 231                                                                                                                                                        IVECO TNK/                        NISSAN P.FINDER
# 232                                                                                                                                                                           V.WAGON SHARON/ JINCHENG AX100
# 233                                                                                                                                                            M.BENZ TRK/                         TYT HIACE
# 234                                                                                                                                                                           M.BENZ MATIC 4/        DAF TRK
# 235                                                                                                                                                                                                TYT HIACE
# 236                                                                                                                                                                                            NISSAN CANTER
# 237                                                                                                                   DAF TNK/                                     DAF TRL/                        TYT HIACE
# 238                                                                                                                                                                                              MAZDA E2000
# 239                                                                                                                                                                                               M.BENZ TRK
# 240                                                                                                                                                                                              FORD GALAXY
# 241                                                                                                                                                                           FORD GALXAY/       BAJAJ BOXER
# 242                                                                                                                                                  DAF TNK/                                        DAF TNK
# 243                                                                                                                                                                        HOWO SINO/              HOWO SINO
# 244                                                                                                                                                           DAF TNK/                             TYT HIACE
# 245                                                                                                                         M.DIESEL TRK/                     IVECO TRK/                           TYT CAMRY
# 246                                                                                                                                                                                               DAF 95 TRK
# 247                                                                                                                                                                                           IVECP EUROSTAR
# 248                                                                                                                                                                                                   DAF 65
# 249                                                                                                                                                                   TYT AVENSIS/               FORD GALAXY
# 250                                                                                                                                                 M.DIESEL TRK/                                  VOLVO TRK
# 251                                                                                                                                                   IVECO TRL/                                MIT. GALLANT
# 252                                                                                                                                                 TYT HIACE/                                     H/RUN TRL
# 253                                                                                                                         TYT SIENNA BUS/                    SCANNA TRK/                         VOLVO TRL
# 254                                                                                                                                                       DAF 95 TRK/                             TYT SIENNA
#
#                   Unnamed: 17
# 0    PROBABLE CAUSE(S) OF RTC
# 1                           s
# 2                         WOV
# 3                     SPV,DGD
# 4                         SPV
# 5                         WOV
# 6                         WOV
# 7                         SPV
# 8                         SPV
# 9                     SPV,DGD
# 10                    SPV,TBT
# 11                    SPV,DGD
# 12                        SPV
# 13                    SPV,DGD
# 14                    DGD,BRD
# 15                        SPV
# 16                        WOV
# 17                        WOV
# 18                        WOV
# 19                        WOV
# 20                    WOV,SPV
# 21                        SPV
# 22                        WOV
# 23                        SPV
# 24                        SPV
# 25                        SPV
# 26                    DGD,SPV
# 27                        DGD
# 28                        TBT
# 29                        WOV
# ..                        ...
# 225                       DGD
# 226                       WOV
# 227                       SPV
# 228                       SPV
# 229                       SPV
# 230                   SPV,OLV
# 231                       SPV
# 232                       SPV
# 233                       BRF
# 234                       WOV
# 235                       TBT
# 236                       WOV
# 237                   SPV,OBS
# 238                       SPV
# 239                       SPV
# 240                       SPV
# 241                       WOV
# 242                       BFL
# 243                       SPV
# 244                       SOS
# 245                       WOV
# 246                       LOC
# 247                   WOV,OVL
# 248                       MDV
# 249                       WOV
# 250                       SPV
# 251                       SPV
# 252                       SPV
# 253                       SPV
# 254                       WOV
#
# [255 rows x 14 columns]

# %%
made.columns=made.iloc[0]
made.head()
# Out:
# 0  S/N  COMMAND      DATE  DAY  CRASH TIME (HRS)    ROUTE  \
# 0  S/N  COMMAND      DATE  DAY  CRASH TIME (HRS)    ROUTE
# 1    a        b         c    c                 d        h
# 2    1  RS11.31  01/01/18  MON              0855  OGB-OYO
# 3    2  RS11.39  03/01/18  WED              1040  OYO-IBD
# 4    3  RS11.31  03/01/18  WED              1121  OGB-OYO
#
# 0                 LOCATION  VEHICLE NUMBER                    VEHICLE NUMBER  \
# 0                 LOCATION  VEHICLE NUMBER                    VEHICLE NUMBER
# 1                        i               j                                 j
# 2               KM7-IBAPON               2          KJA166XM/       WDL522XA
# 3  KM5 4RM IBD-MOBILE AREA               3  KTN207XA/ BDU341XA.     EKY309ZF
# 4               KM7-IBAPON               1                          XA365KMB
#
# 0    VEHICLE CLASS      VEHICLE CATEGORY                  VEHICLE MAKE  \
# 0    VEHICLE CLASS      VEHICLE CATEGORY                  VEHICLE MAKE
# 1                k                     l                             m
# 2     COMM/   COMM         TNK/      TRK            DAF/           DAF
# 3  COMM/COMM/ COMM  TRL/    BUS/     BUS  IVECO/    TOYOTA/     TOYOTA
# 4             COMM                  P.UP                          MIT.
#
# 0                                                         VEHICLE TYPE  \
# 0                                                         VEHICLE TYPE
# 1                                                                    o
# 2                  DAF 95X TNK/                            DAF 95X TRK
# 3  IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 4                                                          MIT. CANTER
#
# 0  PROBABLE CAUSE(S) OF RTC
# 0  PROBABLE CAUSE(S) OF RTC
# 1                         s
# 2                       WOV
# 3                   SPV,DGD
# 4                       SPV

# %%
made=made.drop(0)
made=made.drop(1)
made=made.drop(142)
made=made.drop(143)

made.head()
made=made.reset_index(drop=True)

# %%
made.head()
# Out:
# 0 S/N  COMMAND      DATE  DAY CRASH TIME (HRS)    ROUTE  \
# 0   1  RS11.31  01/01/18  MON             0855  OGB-OYO
# 1   2  RS11.39  03/01/18  WED             1040  OYO-IBD
# 2   3  RS11.31  03/01/18  WED             1121  OGB-OYO
# 3   4  RS11.38  04/01/18  THU             1425  OYO-OGB
# 4   5  RS11.38  06/01/18  SAT             1650  OYO-OGB
#
# 0                  LOCATION VEHICLE NUMBER                    VEHICLE NUMBER  \
# 0                KM7-IBAPON              2          KJA166XM/       WDL522XA
# 1   KM5 4RM IBD-MOBILE AREA              3  KTN207XA/ BDU341XA.     EKY309ZF
# 2                KM7-IBAPON              1                          XA365KMB
# 3    KM2-ODO ASHIPA VILLAGE              3         KSF87QX/     XB624KMA/ NA
# 4  KM3-FED LOW COST HOUSING              2             DKA129XF/    AAA146FB
#
# 0          VEHICLE CLASS      VEHICLE CATEGORY  \
# 0           COMM/   COMM         TNK/      TRK
# 1        COMM/COMM/ COMM  TRL/    BUS/     BUS
# 2                   COMM                  P.UP
# 3  COMM/    COMM/   COMM     TNK/   P.UP/  VAN
# 4            COMM/   PVT          TNK/     CAR
#
# 0                         VEHICLE MAKE  \
# 0                   DAF/           DAF
# 1         IVECO/    TOYOTA/     TOYOTA
# 2                                 MIT.
# 3  MACK/          MAZDA/       BEDFORD
# 4                  TAFAWA/      TOYOTA
#
# 0                                                                             VEHICLE TYPE  \
# 0                                      DAF 95X TNK/                            DAF 95X TRK
# 1                      IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 2                                                                              MIT. CANTER
# 3  MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 4                                                   TAFAWA 418 TNK/              TYT CAMRY
#
# 0 PROBABLE CAUSE(S) OF RTC
# 0                      WOV
# 1                  SPV,DGD
# 2                      SPV
# 3                      WOV
# 4                      WOV

# %%
# save this cleaned df to csv
made.to_csv('cleaned12.csv', index=False)

# %%
made['DATE'] =pd.to_datetime(made['DATE'])

# %%
#e['DATE']=made['DATE']+ pd.to_datetime(made['CRASH TIME (HRS)'].astype('timedelta64[h]'), 'h')

# %%
made['Timestamp']=pd.to_datetime(made.DATE) + made['CRASH TIME (HRS)'].astype('timedelta64[h]')

# %%
made
# Out:
# 0    S/N  COMMAND       DATE  DAY CRASH TIME (HRS)    ROUTE  \
# 0      1  RS11.31 2018-01-01  MON             0855  OGB-OYO
# 1      2  RS11.39 2018-03-01  WED             1040  OYO-IBD
# 2      3  RS11.31 2018-03-01  WED             1121  OGB-OYO
# 3      4  RS11.38 2018-04-01  THU             1425  OYO-OGB
# 4      5  RS11.38 2018-06-01  SAT             1650  OYO-OGB
# 5      6  RS11.31 2018-07-01  SUN             0325  OGB-OYO
# 6      7  RS11.39 2018-10-01  WED             0740  IBD-OYO
# 7      8  RS11.39 2018-10-01  WED             0930  IBD-OYO
# 8      9  RS11.39 2018-12-01  FRI             1150  IBD-OYO
# 9     10  RS11.39 2018-01-15  MON             1940  OYO-IBD
# 10    11  RS11.31 2018-01-17  WED             1625  OGB-ILN
# 11    12  RS11.39 2018-01-22  MON             0600  OYO-IBD
# 12    13  RS11.38 2018-01-24  WED             1630  OYO-OGB
# 13    14  RS11.31 2018-01-27  SAT             1705  OGB-OYO
# 14    15  RS11.38 2018-01-28  SUN             0752  OYO-OGB
# 15    16  RS11.38 2018-01-30  TUE             0900  OYO-OGB
# 16    17  RS11.31 2018-08-02  THU             0910  OGB-OYO
# 17    18  RS11.38 2018-09-02  FRI             0355  OYO-OGB
# 18    19  RS11.38 2018-02-14  WED             1255  OYO-OGB
# 19    20  RS11.31 2018-02-18  SUN             1145  OGB-OYO
# 20    21  RS11.31 2018-02-18  SUN             1730  OGB-OYO
# 21    22  RS11.31 2018-02-20  TUE             1830  OGB-ILN
# 22    23  RS11.31 2018-02-20  TUE             2330  OGB-ILN
# 23    24  RS11.31 2018-02-21  WED             1032  OGB-ILN
# 24    25  RS11.38 2018-02-24  SAT             0935  OYO-OGB
# 25    26  RS11.38 2018-04-03  SUN             1730  OYO-OGB
# 26    27  RS11.38 2018-10-03  SAT             1617  OYO-IBD
# 27    28  RS11.31 2018-10-03  SAT             2000  OGB-OYO
# 28    29  RS11.31 2018-12-03  MON             0201  OGB-ILN
# 29    30  RS11.38 2018-03-14  WED             1610  OYO-OGB
# ..   ...      ...        ...  ...              ...      ...
# 221   83  RS11.38 2017-08-14  MON             1228  OYO-OGB
# 222   84  RS11.38 2017-08-14  MON             2059  OYO-OGB
# 223   86  RS11.31 2017-08-18  FRI             1630  OGB-OYO
# 224   87  RS11.38 2017-08-23  WED             0730  OYO-IBD
# 225   89  RS11.39 2017-08-30  WED             0950  IBD-OYO
# 226   90  RS11.38 2017-08-30  WED             1043  OYO-IBD
# 227   91  RS11.39 2017-02-09  SAT             1445  IBD-OYO
# 228   92  RS11.31 2017-05-09  TUE             0900  OGB-ILN
# 229   93  RS11.31 2017-09-17  SUN             0410  OGB-OYO
# 230   94  RS11.39 2017-09-24  SUN             0900  OYO-IBD
# 231   95  RS11.38 2017-09-25  MON             1330  OYO-OGB
# 232   96  RS11.38 2017-04-10  WED             2100  OYO-OGB
# 233   97  RS11.38 2017-10-10  TUE             0610  OYO-OGB
# 234   98  RS11.38 2017-10-10  TUE             1505  OYO-IBD
# 235   99  RS11.38 2017-10-17  TUE             1146  OYO-OGB
# 236  100  RS11.38 2017-10-18  WED             1255  OYO-OGB
# 237  101  RS11.38 2017-02-11  THU             1415  OYO-OGB
# 238  102  RS11.31 2017-07-11  TUE             1020  OGB-OYO
# 239  103  RS11.38 2017-11-27  MON             1406  OYO-OGB
# 240  104  RS11.31 2017-11-29  WED             0428  OGB-OYO
# 241  105  RS11.38 2017-12-15  FRI             0944  OYO-OGB
# 242  106  RS11.38 2017-12-18  MON             1015  OYO-OGB
# 243  107  RS11.39 2017-12-19  TUE             0445  OYO-IBD
# 244  108  RS11.38 2017-12-20  WED             0845  OYO-IBD
# 245  109  RS11.38 2017-12-21  THU             1340  OYO-OGB
# 246  110  RS11.31 2017-12-22  FRI             2040  OGB-OYO
# 247  111  RS11.31 2017-12-23  SAT             1320  OGB-OYO
# 248  112  RS11.39 2017-12-26  TUE             0720  IBD-OYO
# 249  113  RS11.31 2017-12-28  THU             1300  OGB-OYO
# 250  114  RS11.38 2017-12-29  FRI             1510  OYO-OGB
#
# 0                       LOCATION VEHICLE NUMBER  \
# 0                     KM7-IBAPON              2
# 1        KM5 4RM IBD-MOBILE AREA              3
# 2                     KM7-IBAPON              1
# 3         KM2-ODO ASHIPA VILLAGE              3
# 4       KM3-FED LOW COST HOUSING              2
# 5                      KM5-AGRIC              1
# 6           KM7-DEPEER LIFE AREA              1
# 7                 KM5-TOSHE AREA              2
# 8            OLD RD BY BANK JCTN              2
# 9          4KM 4RM IBD-NNPC JCTN              1
# 10            KM10-AROJE EXPRESS              2
# 11          10KM 4RM IBD-ABE ODO              7
# 12           KM21-BUSARI VILLAGE              2
# 13           KM12-ISANLA VILLAGE              2
# 14              KM4-CUSTOMS AREA              2
# 15               KM1-DURBAR AREA              2
# 16                    KM9-SEKONA              1
# 17                  KM17-ONIGARI              2
# 18          KM10.3-IDODE VILLAGE              2
# 19                KM5-ARINKINKIN              1
# 20                    KM12-ELEGA              2
# 21                   KM19-ABDUKA              1
# 22             KM8-AROJE VILLAGE              1
# 23                  KM19.5-GBEDE              1
# 24               KM2-CUSTOM AREA              1
# 25             KM20-ALAFARA VILL              2
# 26                  KM29-MOTUNDE              1
# 27                     KM13-OLOO              1
# 28             KM9-WINNER CHURCH              2
# 29               KM13.5-ODO OSUN              1
# ..                           ...            ...
# 221                   KM3-ORIAWO              1
# 222                 KM2-AWE JCTN              2
# 223          KM6-ILE ABU, SEKONA              2
# 224                  KM18-FIDITI              1
# 225        KM3- OPP RCC, IDI OSE              2
# 226                  KM15-JOBELE              1
# 227         KM5-POWER LINE, LABI              2
# 228  3KM 4RM LAUTH-AROJE VILLAGE              2
# 229           KM 3-HIGH SCH JUCT              2
# 230        6KM FROM IBD-AKINYELE              2
# 231                 KM17-ALAGBON              1
# 232                  KM6-OFAMETA              1
# 233              KM6-BODE THOMAS              3
# 234                  KM14-FIDITI              1
# 235              KM2-ORIAWO JCTN              1
# 236            KM13.3-ABA LAWYER              1
# 237             KM13-CUSTOM AREA              2
# 238         KM21-IDI EMI VILLAGE              2
# 239         KM12-ALAIDAN VILLAGE              2
# 240          KM15-ALAYIN VILLAGE              2
# 241          KM33-LAWYER VILLAGE              3
# 242          KM2-PACIFIC ACADEMY              1
# 243      5KM 4RM IBD-DEEPER LIFE              1
# 244            KM7-OMOTUNDE AREA              1
# 245              KM17-ABA LAWYER              2
# 246          KM12-IBAPON VILLAGE              2
# 247     KM2.5-AJE IYA FUEL STATE              2
# 248       KM20-AKINYELE TRL PARK              2
# 249           KM20-IPEBA VILLAGE              3
# 250           KM40-OWOYO VILLAGE              2
#
# 0                                                                                                 VEHICLE NUMBER  \
# 0                                                                                       KJA166XM/       WDL522XA
# 1                                                                               KTN207XA/ BDU341XA.     EKY309ZF
# 2                                                                                                       XA365KMB
# 3                                                                                      KSF87QX/     XB624KMA/ NA
# 4                                                                                          DKA129XF/    AAA146FB
# 5                                                                                                       BDU660ZQ
# 6                                                                                                       BDJ430ZQ
# 7                                                                                           LND843XA/         NA
# 8                                                                                           AG801RUM/   KTU429EZ
# 9                                                                                                       KSF591XG
# 10                                                                                         AA471BDA/    LND554ER
# 11   KRD804BG/         EPE997DB/        LSR30XA/       XW962MAN/ GML85XY/       NA/                      MGR16XA
# 12                                                                                       XE455PFA/      LKJ790XU
# 13                                                                                        JJJ318XR/     XB286RLG
# 14                                                                                    KNK153XA/         BDG722QH
# 15                                                                                    AG995FUF/         DTN711QC
# 16                                                                                                       FFA72BW
# 17                                                                           NA/                        LEM563XA
# 18                                                                                        JJJ732XF/     LGB210XA
# 19                                                                                                         UNREG
# 20                                                                                       MUS700XV/      KNR396XA
# 21                                                                                                      XB277BDA
# 22                                                                                                       EPE46QB
# 23                                                                                                      MNA442XV
# 24                                                                                                      KJA570XW
# 25                                                                                       YAB937YJ/       KTG10XA
# 26                                                                                                      YYY891XA
# 27                                                                                                      GML929XA
# 28                                                                                       EPE615XG/      RGB450QB
# 29                                                                                                      BAM154XA
# ..                                                                                                           ...
# 221                                                                                                     FST347XK
# 222                                                                                              YYY942XA/    NA
# 223                                                                           NA/                       LSD471DY
# 224                                                                                                       KTU874
# 225                                                                                            KEH630QC/      NA
# 226                                                                                                     EKY824XD
# 227                                                                                  KJA307BF/          AKD755DM
# 228                                                                                        SEY211AA/    OY6865RS
# 229                                                                                     AA284FFE/       SUL444XA
# 230                                                                                        LSD817ER/    BDU714XA
# 231                                                                                                     LRN651XA
# 232                                                                                                     XG145MKA
# 233                                                                          BNZ887CA/    XA503KUR/     NRR915YQ
# 234                                                                                                     BDS193XA
# 235                                                                                                     XA200GWD
# 236                                                                                                     LEM540XA
# 237                                                                                        ARP705XA/    FMT731QC
# 238                                                                                         KRA174XA/    KWN65ZA
# 239                                                                                       KMC02YQ/      GWL161YJ
# 240                                                                                    NA/               JAL917X
# 241                                                                            KNH373XA/     EPE142XQ/  LSR813DZ
# 242                                                                                                     NSR728ZD
# 243                                                                                                      KTN79XA
# 244                                                                                                     XA170AKD
# 245                                                                                           LSD365AC/ MUM730XA
# 246                                                                                         AKD502XN/   LEM573XA
# 247                                                                                     FKJ289XC/       KRD183EY
# 248                                                                                          FTA668XA/        NA
# 249                                                                            APP321CF/     KRD362XM/  EPE194XQ
# 250                                                                                        MKA292XH/    LSR861EL
#
# 0                                                      VEHICLE CLASS  \
# 0                                                       COMM/   COMM
# 1                                                    COMM/COMM/ COMM
# 2                                                               COMM
# 3                                              COMM/    COMM/   COMM
# 4                                                        COMM/   PVT
# 5                                                                PVT
# 6                                                               COMM
# 7                                                      COMM/    GOVT
# 8                                                         PVT/   PVT
# 9                                                               COMM
# 10                                                        PVT/   PVT
# 11   PVT/    PVT/    COMM/    COMM/       COMM/      COMM/      COMM
# 12                                                       COMM/  COMM
# 13                                                       COMM/  COMM
# 14                                                     COMM/    COMM
# 15                                                 PVT/         COMM
# 16                                                               PVT
# 17                                                      COMM/   COMM
# 18                                                       COMM/  COMM
# 19                                                              COMM
# 20                                                       COMM/  COMM
# 21                                                              COMM
# 22                                                               PVT
# 23                                                              COMM
# 24                                                              COMM
# 25                                                       COMM/  COMM
# 26                                                              COMM
# 27                                                              COMM
# 28                                                      COMM/   COMM
# 29                                                              COMM
# ..                                                               ...
# 221                                                             COMM
# 222                                                      COMM/  COMM
# 223                                                       PVT/   PVT
# 224                                                              PVT
# 225                                                      COMM/  COMM
# 226                                                             COMM
# 227                                                       COMM/  PVT
# 228                                                        PVT/  PVT
# 229                                                    COMM/    COMM
# 230                                                       PVT/  COMM
# 231                                                             COMM
# 232                                                             COMM
# 233                                           COMM/    COMM/    COMM
# 234                                                             COMM
# 235                                                             COMM
# 236                                                             COMM
# 237                                                      COMM/  COMM
# 238                                                     COMM/   COMM
# 239                                                    COMM/    COMM
# 240                                                    COMM/    COMM
# 241                                             COMM/    COMM/   PVT
# 242                                                             COMM
# 243                                                             COMM
# 244                                                             COMM
# 245                                                        PVT/ COMM
# 246                                                      COMM/  COMM
# 247                                                     COMM/    PVT
# 248                                                     COMM/   COMM
# 249                                               PVT/  COMM/   COMM
# 250                                                      COMM/   PVT
#
# 0                                              VEHICLE CATEGORY  \
# 0                                                 TNK/      TRK
# 1                                          TRL/    BUS/     BUS
# 2                                                          P.UP
# 3                                             TNK/   P.UP/  VAN
# 4                                                  TNK/     CAR
# 5                                                           BUS
# 6                                                           CAR
# 7                                               TNK/        BUS
# 8                                                     CAR/  CAR
# 9                                                           BUS
# 10                                               P.UP/      SUV
# 11   CAR/    BUS/     CAR/      TRL/       TRK/      TRL/   TRL
# 12                                                  BUS/    TNK
# 13                                                  BUS/    BUS
# 14                                                   TNK/    MC
# 15                                                   CAR/    MC
# 16                                                          CAR
# 17                                                  TNK/    BUS
# 18                                                  BUS/    BUS
# 19                                                           MC
# 20                                                   BUS/   BUS
# 21                                                         P.UP
# 22                                                          TRK
# 23                                                          TRK
# 24                                                          BUS
# 25                                                   TNK/   TRL
# 26                                                          BUS
# 27                                                         P.UP
# 28                                                 TRL/      MC
# 29                                                          TNK
# ..                                                          ...
# 221                                                         TNK
# 222                                                    BUS/  MC
# 223                                                   CAR/  CAR
# 224                                                         SUV
# 225                                                  MC/    TRL
# 226                                                         BUS
# 227                                              TNK/       SUV
# 228                                                   BUS/   MC
# 229                                                  TRK/   BUS
# 230                                               CAR/      TRK
# 231                                                         BUS
# 232                                                        P.UP
# 233                                      TNK/   TRL/        BUS
# 234                                                         BUS
# 235                                                         TRK
# 236                                                         BUS
# 237                                                   BUS/   MC
# 238                                                 TNK/    TNK
# 239                                                  TRK/   TRK
# 240                                                TNK/     BUS
# 241                                           TRK/  TRK/    CAR
# 242                                                         TRK
# 243                                                         TRL
# 244                                                         TRK
# 245                                                   CAR/  CAR
# 246                                                  TRK/   TRK
# 247                                                 TRL/    CAR
# 248                                              BUS/       TRL
# 249                                         BUS/    TRK/    TRL
# 250                                                  TRK/   BUS
#
# 0                                                                                        VEHICLE MAKE  \
# 0                                                                                  DAF/           DAF
# 1                                                                        IVECO/    TOYOTA/     TOYOTA
# 2                                                                                                MIT.
# 3                                                                 MACK/          MAZDA/       BEDFORD
# 4                                                                                 TAFAWA/      TOYOTA
# 5                                                                                                FORD
# 6                                                                                             V.WAGON
# 7                                                                            MACK/             TOYOTA
# 8                                                                               HYUNDAI/      V.WAGON
# 9                                                                                              TOYOTA
# 10                                                                           DATSUN/           TOYOTA
# 11   HYUNDI/    TOYOTA/          NISSAN/          M.DIESEL/       IVECO/         NA/             MACK
# 12                                                                                 MAZDA/       IVECO
# 13                                                                                TOYOTA/      TOYOTA
# 14                                                                         IVECO/               BAJAJ
# 15                                                                                  MAZDA/      BAJAJ
# 16                                                                                             M.BENZ
# 17                                                                       MACK/                 TOYOTA
# 18                                                                                 MAZDA/       MAZDA
# 19                                                                                             BAJAJ
# 20                                                                                TOYOTA/      TOYOTA
# 21                                                                                               MIT.
# 22                                                                                              IVECO
# 23                                                                                              IVECO
# 24                                                                                             SUZUKI
# 25                                                                    DAF/                        DAF
# 26                                                                                              MAZDA
# 27                                                                                               MIT.
# 28                                                                                    IVECO/    BAJAJ
# 29                                                                                              IVECO
# ..                                                                                                ...
# 221                                                                                              EURO
# 222                                                                                     MAZDA/  BAJAJ
# 223                                                                                   V.WAGON/    PGT
# 224                                                                                            TOYOTA
# 225                                                                        BAJAJ/                  NA
# 226                                                                                            TOYOTA
# 227                                                                                 IVECO/     NISSAN
# 228                                                                             V.WAGON/     JINCHENG
# 229                                                                             M.BENZ/        TOYOTA
# 230                                                                                    M.BENZ/    DAF
# 231                                                                                            TOYOTA
# 232                                                                                            NISSAN
# 233                                                    DAF/                DAF/                TOYOTA
# 234                                                                                             MAZDA
# 235                                                                                            M.BENZ
# 236                                                                                              FORD
# 237                                                                                    FORD/   BAJAJA
# 238                                                                       DAF/                    DAF
# 239                                                                                HOWO/         HOWO
# 240                                                                      DAF/                  TOYOTA
# 241                                                               M.DIESEL/       IVECO/       TOYOTA
# 242                                                                                               DAF
# 243                                                                                             IVECO
# 244                                                                                               DAF
# 245                                                                                   TOYOTA/    FORD
# 246                                                                                M.DIESEL/    VOLVO
# 247                                                                          IVECO/              MIT.
# 248                                                                           TOYOTA/              NA
# 249                                                                     TOYOTA/    SCANNA/      VOLVO
# 250                                                                    DAF/                    TOYOTA
#
# 0                                                                                                                                                                                               VEHICLE TYPE  \
# 0                                                                                                                                                        DAF 95X TNK/                            DAF 95X TRK
# 1                                                                                                                                        IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 2                                                                                                                                                                                                MIT. CANTER
# 3                                                                                                                    MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 4                                                                                                                                                                     TAFAWA 418 TNK/              TYT CAMRY
# 5                                                                                                                                                                                                FORD GALAXY
# 6                                                                                                                                                                                               V.WAGON GULF
# 7                                                                                                                                                    MACK TNK/                                   TYT COASTER
# 8                                                                                                                                                                     HYUNDAI LANTRA/           V.WAGON GULF
# 9                                                                                                                                                                                                  TYT HIACE
# 10                                                                                                                                                              DATSUN P.UP/                      TYT TUNDRA
# 11   HYUNDAI SONATA/         TYT PICNIC/                           NISSAN MICRA/                 M.DIESEL TRL/                                          IVECO TRL/                                   NA/ ...
# 12                                                                                                                                                                   MAZDA E2000/                  IVECO TNK
# 13                                                                                                                                                                            TYT SIENNA/          TYT HIACE
# 14                                                                                                                                                           IVECO TNK/                          BAJAJ BOXER
# 15                                                                                                                                                          MAZDA 626/                           BAJAJ BOXER
# 16                                                                                                                                                                                              M.BENZ C240
# 17                                                                                                                                                         MACK TNK/                               TYT HIACE
# 18                                                                                                                                                          MAZDA E2000/                         MAZDA E2000
# 19                                                                                                                                                                                               BAJAJ BOXER
# 20                                                                                                                                                        TYT HIACE/                               TYT HIACE
# 21                                                                                                                                                                                               MIT. CANTER
# 22                                                                                                                                                                                                IVECO  TRK
# 23                                                                                                                                                                                                IVECO  TRK
# 24                                                                                                                                                                                            SUZUKI MIDIBUS
# 25                                                                                                                                                          DAF TNK/                                 DAF TRL
# 26                                                                                                                                                                                               MAZDA E2000
# 27                                                                                                                                                                                               MIT. CANTER
# 28                                                                                                                                                                         IVECO EUROSAL/        BAJAJ BOXER
# 29                                                                                                                                                                                                 IVECO TNK
# ..                                                                                                                                                                                                       ...
# 221                                                                                                                                                                                            EURO STAR TNK
# 222                                                                                                                                                                            MAZDA E2000/      BAJAJ BOXER
# 223                                                                                                                                                                 V.WAGON GULF/                    PGT 206
# 224                                                                                                                                                                                                 TYT RAV4
# 225                                                                                                                                                               BAJAJ BOXER/                 HIT & RUN TRL
# 226                                                                                                                                                                                                TYT HIACE
# 227                                                                                                                                                        IVECO TNK/                        NISSAN P.FINDER
# 228                                                                                                                                                                           V.WAGON SHARON/ JINCHENG AX100
# 229                                                                                                                                                            M.BENZ TRK/                         TYT HIACE
# 230                                                                                                                                                                           M.BENZ MATIC 4/        DAF TRK
# 231                                                                                                                                                                                                TYT HIACE
# 232                                                                                                                                                                                            NISSAN CANTER
# 233                                                                                                                   DAF TNK/                                     DAF TRL/                        TYT HIACE
# 234                                                                                                                                                                                              MAZDA E2000
# 235                                                                                                                                                                                               M.BENZ TRK
# 236                                                                                                                                                                                              FORD GALAXY
# 237                                                                                                                                                                           FORD GALXAY/       BAJAJ BOXER
# 238                                                                                                                                                  DAF TNK/                                        DAF TNK
# 239                                                                                                                                                                        HOWO SINO/              HOWO SINO
# 240                                                                                                                                                           DAF TNK/                             TYT HIACE
# 241                                                                                                                         M.DIESEL TRK/                     IVECO TRK/                           TYT CAMRY
# 242                                                                                                                                                                                               DAF 95 TRK
# 243                                                                                                                                                                                           IVECP EUROSTAR
# 244                                                                                                                                                                                                   DAF 65
# 245                                                                                                                                                                   TYT AVENSIS/               FORD GALAXY
# 246                                                                                                                                                 M.DIESEL TRK/                                  VOLVO TRK
# 247                                                                                                                                                   IVECO TRL/                                MIT. GALLANT
# 248                                                                                                                                                 TYT HIACE/                                     H/RUN TRL
# 249                                                                                                                         TYT SIENNA BUS/                    SCANNA TRK/                         VOLVO TRL
# 250                                                                                                                                                       DAF 95 TRK/                             TYT SIENNA
#
# 0   PROBABLE CAUSE(S) OF RTC           Timestamp
# 0                        WOV 2018-02-05 15:00:00
# 1                    SPV,DGD 2018-04-13 08:00:00
# 2                        SPV 2018-04-16 17:00:00
# 3                        WOV 2018-05-30 09:00:00
# 4                        WOV 2018-08-08 18:00:00
# 5                        SPV 2018-07-14 13:00:00
# 6                        SPV 2018-10-31 20:00:00
# 7                    SPV,DGD 2018-11-08 18:00:00
# 8                    SPV,TBT 2019-01-17 22:00:00
# 9                    SPV,DGD 2018-04-05 20:00:00
# 10                       SPV 2018-03-25 17:00:00
# 11                   SPV,DGD 2018-02-16 00:00:00
# 12                   DGD,BRD 2018-04-01 22:00:00
# 13                       SPV 2018-04-08 01:00:00
# 14                       WOV 2018-02-28 08:00:00
# 15                       WOV 2018-03-08 12:00:00
# 16                       WOV 2018-09-08 22:00:00
# 17                       WOV 2018-09-16 19:00:00
# 18                   WOV,SPV 2018-04-07 07:00:00
# 19                       SPV 2018-04-06 17:00:00
# 20                       WOV 2018-05-01 02:00:00
# 21                       SPV 2018-05-07 06:00:00
# 22                       SPV 2018-05-28 02:00:00
# 23                       SPV 2018-04-05 00:00:00
# 24                   DGD,SPV 2018-04-03 23:00:00
# 25                       DGD 2018-06-14 02:00:00
# 26                       TBT 2018-12-09 09:00:00
# 27                       WOV 2018-12-25 08:00:00
# 28                       NJR 2018-12-11 09:00:00
# 29                   DGD,SPV 2018-05-20 02:00:00
# ..                       ...                 ...
# 221                      DGD 2017-10-04 04:00:00
# 222                      WOV 2017-11-07 19:00:00
# 223                      SPV 2017-10-24 22:00:00
# 224                      SPV 2017-09-22 10:00:00
# 225                      SPV 2017-10-08 14:00:00
# 226                  SPV,OLV 2017-10-12 11:00:00
# 227                      SPV 2017-04-10 05:00:00
# 228                      SPV 2017-06-15 12:00:00
# 229                      BRF 2017-10-04 02:00:00
# 230                      WOV 2017-10-31 12:00:00
# 231                      TBT 2017-11-19 10:00:00
# 232                      WOV 2017-07-06 12:00:00
# 233                  SPV,OBS 2017-11-04 10:00:00
# 234                      SPV 2017-12-11 17:00:00
# 235                      SPV 2017-12-03 18:00:00
# 236                      SPV 2017-12-09 07:00:00
# 237                      WOV 2017-04-10 23:00:00
# 238                      BFL 2017-08-22 12:00:00
# 239                      SPV 2018-01-24 14:00:00
# 240                      SOS 2017-12-16 20:00:00
# 241                      WOV 2018-01-23 08:00:00
# 242                      LOC 2018-01-29 07:00:00
# 243                  WOV,OVL 2018-01-06 13:00:00
# 244                      MDV 2018-01-24 05:00:00
# 245                      WOV 2018-02-14 20:00:00
# 246                      SPV 2018-03-17 00:00:00
# 247                      SPV 2018-02-16 00:00:00
# 248                      SPV 2018-01-25 00:00:00
# 249                      SPV 2018-02-20 04:00:00
# 250                      WOV 2018-03-01 22:00:00
#
# [251 rows x 15 columns]

# %%
#made=made.drop(['DATE','DAY'],axis=1)

# %%
made['VEHICLE CLASS']
# Out:
# 0                                                         COMM/   COMM
# 1                                                      COMM/COMM/ COMM
# 2                                                                 COMM
# 3                                                COMM/    COMM/   COMM
# 4                                                          COMM/   PVT
# 5                                                                  PVT
# 6                                                                 COMM
# 7                                                        COMM/    GOVT
# 8                                                           PVT/   PVT
# 9                                                                 COMM
# 10                                                          PVT/   PVT
# 11     PVT/    PVT/    COMM/    COMM/       COMM/      COMM/      COMM
# 12                                                         COMM/  COMM
# 13                                                         COMM/  COMM
# 14                                                       COMM/    COMM
# 15                                                   PVT/         COMM
# 16                                                                 PVT
# 17                                                        COMM/   COMM
# 18                                                         COMM/  COMM
# 19                                                                COMM
# 20                                                         COMM/  COMM
# 21                                                                COMM
# 22                                                                 PVT
# 23                                                                COMM
# 24                                                                COMM
# 25                                                         COMM/  COMM
# 26                                                                COMM
# 27                                                                COMM
# 28                                                        COMM/   COMM
# 29                                                                COMM
#                                     ...
# 221                                                               COMM
# 222                                                        COMM/  COMM
# 223                                                         PVT/   PVT
# 224                                                                PVT
# 225                                                        COMM/  COMM
# 226                                                               COMM
# 227                                                         COMM/  PVT
# 228                                                          PVT/  PVT
# 229                                                      COMM/    COMM
# 230                                                         PVT/  COMM
# 231                                                               COMM
# 232                                                               COMM
# 233                                             COMM/    COMM/    COMM
# 234                                                               COMM
# 235                                                               COMM
# 236                                                               COMM
# 237                                                        COMM/  COMM
# 238                                                       COMM/   COMM
# 239                                                      COMM/    COMM
# 240                                                      COMM/    COMM
# 241                                               COMM/    COMM/   PVT
# 242                                                               COMM
# 243                                                               COMM
# 244                                                               COMM
# 245                                                          PVT/ COMM
# 246                                                        COMM/  COMM
# 247                                                       COMM/    PVT
# 248                                                       COMM/   COMM
# 249                                                 PVT/  COMM/   COMM
# 250                                                        COMM/   PVT
# Name: VEHICLE CLASS, Length: 251, dtype: object

# %%
made=made.drop(['DATE','CRASH TIME (HRS)'],axis=1)

# %%
made.head()
# Out:
# 0 S/N  COMMAND  DAY    ROUTE                  LOCATION VEHICLE NUMBER  \
# 0   1  RS11.31  MON  OGB-OYO                KM7-IBAPON              2
# 1   2  RS11.39  WED  OYO-IBD   KM5 4RM IBD-MOBILE AREA              3
# 2   3  RS11.31  WED  OGB-OYO                KM7-IBAPON              1
# 3   4  RS11.38  THU  OYO-OGB    KM2-ODO ASHIPA VILLAGE              3
# 4   5  RS11.38  SAT  OYO-OGB  KM3-FED LOW COST HOUSING              2
#
# 0                    VEHICLE NUMBER          VEHICLE CLASS  \
# 0          KJA166XM/       WDL522XA           COMM/   COMM
# 1  KTN207XA/ BDU341XA.     EKY309ZF        COMM/COMM/ COMM
# 2                          XA365KMB                   COMM
# 3         KSF87QX/     XB624KMA/ NA  COMM/    COMM/   COMM
# 4             DKA129XF/    AAA146FB            COMM/   PVT
#
# 0      VEHICLE CATEGORY                         VEHICLE MAKE  \
# 0         TNK/      TRK                   DAF/           DAF
# 1  TRL/    BUS/     BUS         IVECO/    TOYOTA/     TOYOTA
# 2                  P.UP                                 MIT.
# 3     TNK/   P.UP/  VAN  MACK/          MAZDA/       BEDFORD
# 4          TNK/     CAR                  TAFAWA/      TOYOTA
#
# 0                                                                             VEHICLE TYPE  \
# 0                                      DAF 95X TNK/                            DAF 95X TRK
# 1                      IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 2                                                                              MIT. CANTER
# 3  MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 4                                                   TAFAWA 418 TNK/              TYT CAMRY
#
# 0 PROBABLE CAUSE(S) OF RTC           Timestamp
# 0                      WOV 2018-02-05 15:00:00
# 1                  SPV,DGD 2018-04-13 08:00:00
# 2                      SPV 2018-04-16 17:00:00
# 3                      WOV 2018-05-30 09:00:00
# 4                      WOV 2018-08-08 18:00:00

# %%
def tenure(x):
    if x == 'COMM/COMM/ COMM':
        return 'Commercial'
    if x == 'COMM/   COMM':
        return 'Commercial'
    elif x == 'COMM':
        return 'Commercial'
    elif x == 'PVT/   PVT':
        return 'Private'
    elif x == 'PVT':
        return 'Private'
    else:
        return 'both'

# %%
made['VEHICLE CLASS'] = made['VEHICLE CLASS'].apply(tenure)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
made['VEHICLE NUMBER'].nunique()
# Out:
# 0
# VEHICLE NUMBER      6
# VEHICLE NUMBER    251
# dtype: int64

# %%
made.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 13 columns):
# S/N                         251 non-null object
# COMMAND                     251 non-null object
# DAY                         251 non-null object
# ROUTE                       251 non-null object
# LOCATION                    251 non-null object
# VEHICLE NUMBER              251 non-null object
# VEHICLE NUMBER              251 non-null object
# VEHICLE CLASS               251 non-null object
# VEHICLE CATEGORY            251 non-null object
# VEHICLE MAKE                251 non-null object
# VEHICLE TYPE                251 non-null object
# PROBABLE CAUSE(S) OF RTC    251 non-null object
# Timestamp                   251 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 25.6+ KB

# %%
made.to_csv('cleandata.csv', index=False)

# %%
made.head(
)
# Out:
# 0 S/N  COMMAND  DAY    ROUTE                  LOCATION VEHICLE NUMBER  \
# 0   1  RS11.31  MON  OGB-OYO                KM7-IBAPON              2
# 1   2  RS11.39  WED  OYO-IBD   KM5 4RM IBD-MOBILE AREA              3
# 2   3  RS11.31  WED  OGB-OYO                KM7-IBAPON              1
# 3   4  RS11.38  THU  OYO-OGB    KM2-ODO ASHIPA VILLAGE              3
# 4   5  RS11.38  SAT  OYO-OGB  KM3-FED LOW COST HOUSING              2
#
# 0                    VEHICLE NUMBER VEHICLE CLASS      VEHICLE CATEGORY  \
# 0          KJA166XM/       WDL522XA    Commercial         TNK/      TRK
# 1  KTN207XA/ BDU341XA.     EKY309ZF    Commercial  TRL/    BUS/     BUS
# 2                          XA365KMB    Commercial                  P.UP
# 3         KSF87QX/     XB624KMA/ NA          both     TNK/   P.UP/  VAN
# 4             DKA129XF/    AAA146FB          both          TNK/     CAR
#
# 0                         VEHICLE MAKE  \
# 0                   DAF/           DAF
# 1         IVECO/    TOYOTA/     TOYOTA
# 2                                 MIT.
# 3  MACK/          MAZDA/       BEDFORD
# 4                  TAFAWA/      TOYOTA
#
# 0                                                                             VEHICLE TYPE  \
# 0                                      DAF 95X TNK/                            DAF 95X TRK
# 1                      IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 2                                                                              MIT. CANTER
# 3  MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 4                                                   TAFAWA 418 TNK/              TYT CAMRY
#
# 0 PROBABLE CAUSE(S) OF RTC           Timestamp
# 0                      WOV 2018-02-05 15:00:00
# 1                  SPV,DGD 2018-04-13 08:00:00
# 2                      SPV 2018-04-16 17:00:00
# 3                      WOV 2018-05-30 09:00:00
# 4                      WOV 2018-08-08 18:00:00

# %%
made.LOCATION.unique()
# Out:
# array(['KM7-IBAPON', 'KM5 4RM IBD-MOBILE AREA', 'KM2-ODO ASHIPA VILLAGE',
#        'KM3-FED LOW COST HOUSING', 'KM5-AGRIC', 'KM7-DEPEER LIFE AREA',
#        'KM5-TOSHE AREA', 'OLD RD BY BANK JCTN', '4KM 4RM IBD-NNPC JCTN',
#        'KM10-AROJE EXPRESS', '10KM 4RM IBD-ABE ODO',
#        'KM21-BUSARI VILLAGE', 'KM12-ISANLA VILLAGE', 'KM4-CUSTOMS AREA',
#        'KM1-DURBAR AREA', 'KM9-SEKONA', 'KM17-ONIGARI',
#        'KM10.3-IDODE VILLAGE', 'KM5-ARINKINKIN', 'KM12-ELEGA',
#        'KM19-ABDUKA', 'KM8-AROJE VILLAGE', 'KM19.5-GBEDE',
#        'KM2-CUSTOM AREA', 'KM20-ALAFARA VILL', 'KM29-MOTUNDE',
#        'KM13-OLOO', 'KM9-WINNER CHURCH', 'KM13.5-ODO OSUN',
#        'KM4-ILORA BRIDGE 2', 'KM29-IKPEBA VILLAGE', 'KM16-IDODE VILLAGE',
#        'KM4-SABO PARK', 'KM18-IDI IGBA VILLAGE', 'KM4-SAGBE JCTN',
#        'KM20-ONIGARI', 'KM6-AGRIC AREA',
#        '15KM 4RM IBD-KOLADAISI UNIVERSITY', 'KM4.5-OANDO FUEL/S',
#        'KM15-KOLADAISI UNI. AREA', 'KM4-OLOO POLICE POST ADETUNJI VIL.',
#        'KM12.2-ABA LAWYER VIL.', 'KM13-TAKIE& ASANI VILLAGE',
#        'KM6-BEST AHOYAYA GARAGE', 'KM13-OWEYO VILLAGE',
#        'KM4-TAKIE FRONT NTA STATION', 'KM7-DEEPER LIFE AREA',
#        'KM21-TAKIE ITAORAN', 'KM6-TAKIE ILE-ABU', 'KM4.3-IDI ORI',
#        'KM6-NNPC OPP. IYANA APAPA', 'KM12-ITOKUN', 'KM11-ELEGA VILLAGE',
#        'KM19-ADETUNJI VILLAGE', 'KM1-NTA JCTN AWE', 'KM11-JOBELE',
#        'KM9-WAS MKT, BEHIND WINNER', 'KM20-IJWAYA VILLAGE', 'KM10-JOBELE',
#        'KM1-AJEGUNLE MKT', 'KM1-TAKIE RBT', 'KM10-IROKO AREA',
#        'KM1.5-LOW COST HSING AREA', 'KM8-ROYAL SEED EVENT CENTER',
#        'AKINYELE AREA', '500M 4RM ALATA FLOUR MILL- ELEGA VILLAGE',
#        'KM9-FRSC OFFICE', 'KM8-ILORA', 'KM21.3- ONUGARI VILLAGE',
#        'KM11.3-AGBOYE VILLAGE', 'KM3-OLIVET G/SCH AREA',
#        '7KM 4RM IBD-TOSE AREA', '12KM 4RM IBD-KOLADIASE UNIVERSITY AREA',
#        'KM20-IJAWAYA VILLAGE', 'KM7-HIGH SCHOOL',
#        'KM25-KOLA DAISI UNIVERSITY AREA', 'KM9-AGRIC AREA',
#        '2 KM 4RM IBD-RCC AREA', 'KM20-FIDITI',
#        'KM1.5 PALACE RD BY AKESAN MKT JCTN',
#        'KM14-B4 KOLADAISI UNIVERSITY', 'KM10-SEKONA VILLAGE',
#        'KM1-AWE JCTN', 'KM7.5-BABA IBADAN VILLAGE', 'KM8-AGBOYE VILLAGE',
#        'KM2-IDE OSE', 'KM4-NTA JUCTN', 'KM11-ABUDUKA VILLAGE',
#        'KM8.5-LAWYER VILLAGE', 'KM3-LADIGBOLU, OYO',
#        'KM8-DEEPER LIFE AREA', 'KM12-OOLO VILLAGE', 'KM3.5-NTA JCTN',
#        'KM23-BUSARI VILLAGE', 'KM35-JOBELE', 'KM3.5-HIGH SCHOOL AREA',
#        'KM12-ONIGARI VILLAGE', 'KM4.5-ISALE HIGH SCHOOL',
#        'KM12-MONTUNDE VILLAGE', 'KM11-BABA IBADAN', 'KM4.5- CARETAKER',
#        'KM2.5-NTA', 'KM8-ABA-ODO AREA', 'KM2-OJOGBODU',
#        'KM5-LAREK FUEL/S', 'KM16-IJAWAYA VILLAGE', 'KM0.7 ADIKUTA RD',
#        '8KM 4RM IBD-DEEPER LIFE AREA', '200M-SKYE BANK',
#        'KM10-ILE-ABU VILLAGE/ODO-OBA', 'KM18-FIDITI', 'KM10-AGBOYE',
#        'KM1-ILORA BRIDGE', 'KM1-SCH OF SURVEY AREA', 'KM1-ODO ORU JCTN',
#        'KM1-RANDAH R/A BY BOWEN HOSP', 'KM8- AJE IYA FUEL/S',
#        'KM12.3-AGBOYE VILLAGE', 'KM16-IROKO AFTER KOLADAISI VERSITY',
#        'IROKO', 'KM10-MECHANIC VILLAGE', 'KM11.5-ABA LAWYER',
#        'KM8.5-SEKONA VILLAGE', '5KM 4RM OJOO-RCC', 'KM17-FIDITI',
#        '10KM 4RM IBD-AKINYELE UNDER BRIDGE', 'KM15-OOLO COM GRAM SCH',
#        'KM7-ILORA BRIDGE', 'KM17-ASANI ELEGA VILLAGE',
#        'KM4.5-HIGH SCH JCTN', 'KM5-FRSC BASE', 'TOSE', 'KM8-AGBOYE',
#        'KM5-TAKIE', '15KM-ODO OBA', 'KM11-LAWYER ', 'KM25-IPEBA VILLAGE',
#        'KM18-ALAIDAN', 'KM2-OLIVET', 'KM12-JOBELE', 'KM3-AJAIYA AREA',
#        'KM10-ELEKARA', 'DEEPER LIFE JCTN', 'KM17-OWEYO VILLAGE',
#        'KM6-GTB', 'KM22-ALABON VILLAGE', 'FRSC BASE', 'KM20HIGH SCH',
#        'KM6-ILE ABU', 'KM15-IJAWAYA', 'KM8-OJA WASO', 'ISAJOG FUEL/S',
#        'AKINYELE UNDER BRIDGE', 'KM2-SKYE BANK', 'KM1- ST BENNAD',
#        'KM2-SAW MILL', 'KM4-CARETAKER JCTN', 'KM3-SEKONA', 'RCC COMPANY',
#        'KM1-OJOO AREA', 'KM5-AGBOYE', 'KM3-ACCESS BANK',
#        '3KM TO AGRIC-IBAPON', '2KM TO AGRIC-IBAPON',
#        '4KM OLOPEMARUN TO FRSC OFFICE', '2KM AWE JUNCTION TO OYO',
#        'KM5 CUSTOM', 'KM 12 JOBELE TO OYO', 'KM 25 IROKO VILLAGE OYO',
#        'KM5 CUSTOM TO OYO', '4KM ABUDUKA TO ORILE IGBON',
#        'KM17 IROKO TO OJO', 'KM4 TO OYO', 'KM8 DANGOTE PARK TO OYO',
#        'KM2 AJEGUNLE TO OYO', '2KM RCC AREA TO AJAAWA JUNCTION',
#        '5KM OLOO TO ODO-OBA MARKET',
#        '2KM BACK OF OJA WASO TO WINNERS CHURCH',
#        'KM3 AHOYAYA GARAGE TO BASE', 'KM4 ORIAWO JUNCTION TO OYO',
#        '5KM BACK OF ALATA FLOUR MILLS TO LAUTECH', 'KM15 ALAIDAN TO OYO',
#        'KM2 OLOOBRIDGE ', '2KM 4RM AGRIC AREA- SEKONA', 'KM6-CUSTOM',
#        'KM1 - FRSC BASE', 'KM13-ODO OSUN', 'KM3-HAWOYAYA GRAMMER SCH',
#        'KM8-DANGOTE PARK', 'KM21-IPEBA VILLAGE', 'KM1-OJOO INTERCHANGE',
#        'KM8-MONIYA B/STOP', '3KM TO ODO OBA-OLOO', 'KM5-CUSTOM ',
#        '2KM TO HIGH SCH- OLOPEMARUN', '3KM 4RM BASE-AKINYELE BRIDGE',
#        '3KMRM WINNER-UNDER BRIDGE OJA WASO', 'KM2-AWE JCTN',
#        'KM16-FIDITI', '4KM 4RM ODOOBA-IBAPON', 'KM4-MR BIGGS',
#        '3KM 4RM ODOOBA-ILE ABU', 'KM4-BODE THOMAS',
#        '6KM 4RM LAUTECH-GAMBARI', '4KM 4RM HIGH SCH-OLOPE MARUN',
#        'KM3-ORIAWO', 'KM6-ILE ABU, SEKONA', 'KM3- OPP RCC, IDI OSE',
#        'KM15-JOBELE', 'KM5-POWER LINE, LABI',
#        '3KM 4RM LAUTH-AROJE VILLAGE', 'KM 3-HIGH SCH JUCT',
#        '6KM FROM IBD-AKINYELE', 'KM17-ALAGBON', 'KM6-OFAMETA',
#        'KM6-BODE THOMAS', 'KM14-FIDITI', 'KM2-ORIAWO JCTN',
#        'KM13.3-ABA LAWYER', 'KM13-CUSTOM AREA', 'KM21-IDI EMI VILLAGE',
#        'KM12-ALAIDAN VILLAGE', 'KM15-ALAYIN VILLAGE',
#        'KM33-LAWYER VILLAGE', 'KM2-PACIFIC ACADEMY',
#        '5KM 4RM IBD-DEEPER LIFE', 'KM7-OMOTUNDE AREA', 'KM17-ABA LAWYER',
#        'KM12-IBAPON VILLAGE', 'KM2.5-AJE IYA FUEL STATE',
#        'KM20-AKINYELE TRL PARK', 'KM20-IPEBA VILLAGE',
#        'KM40-OWOYO VILLAGE'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

for i in ["COMMAND", "LOCATION", "DAY"]:
    made[i] = LabelEncoder().fit_transform(made[i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
made.head()
# Out:
# 0 S/N  COMMAND  DAY    ROUTE  LOCATION VEHICLE NUMBER  \
# 0   1        0    1  OGB-OYO       207              2
# 1   2        2    7  OYO-IBD       182              3
# 2   3        0    7  OGB-OYO       207              1
# 3   4        1    4  OYO-OGB       122              3
# 4   5        1    2  OYO-OGB       154              2
#
# 0                    VEHICLE NUMBER VEHICLE CLASS      VEHICLE CATEGORY  \
# 0          KJA166XM/       WDL522XA    Commercial         TNK/      TRK
# 1  KTN207XA/ BDU341XA.     EKY309ZF    Commercial  TRL/    BUS/     BUS
# 2                          XA365KMB    Commercial                  P.UP
# 3         KSF87QX/     XB624KMA/ NA          both     TNK/   P.UP/  VAN
# 4             DKA129XF/    AAA146FB          both          TNK/     CAR
#
# 0                         VEHICLE MAKE  \
# 0                   DAF/           DAF
# 1         IVECO/    TOYOTA/     TOYOTA
# 2                                 MIT.
# 3  MACK/          MAZDA/       BEDFORD
# 4                  TAFAWA/      TOYOTA
#
# 0                                                                             VEHICLE TYPE  \
# 0                                      DAF 95X TNK/                            DAF 95X TRK
# 1                      IVECO EUROSTAR/         TYT HIACE/                       TYT PREVIA
# 2                                                                              MIT. CANTER
# 3  MACK TNK/                         MAZDA P.UP/                               BEDFORD VAN
# 4                                                   TAFAWA 418 TNK/              TYT CAMRY
#
# 0 PROBABLE CAUSE(S) OF RTC           Timestamp
# 0                      WOV 2018-02-05 15:00:00
# 1                  SPV,DGD 2018-04-13 08:00:00
# 2                      SPV 2018-04-16 17:00:00
# 3                      WOV 2018-05-30 09:00:00
# 4                      WOV 2018-08-08 18:00:00

# %%
static_feature_names = [
    'S/N',
    'COMMAND',
    'DAY',
    'ROUTE',
    'LOCATION',
    'VEHICLE_NUMBER',
    'VEHICLE_CLASS',
    'VEHICLE_CATEGORY',
    'VEHICLE_MAKE',
    'VEHICLE_TYPE',
    'PROBABLE_CAUSE(S)_OF_RTC',
    'Timestamp'
]
temporal_feature_names = [
    'hour',
    'weekday',
    'month'
]

# %%
class NegativeSampler:
    """
    Given features (positive examples), roads, times and the number of samples to draw, draws a sample
    """
    def __init__(self,num_samples,
                 accidents,roads,
                 static_feature_names,
                 seed=None):
        'static_feature_names

        self.roads = roads
        self.accidents = accidents
        self.num_samples = num_samples
        
        self.static_feature_names = static_feature_names
        
        if seed:
            np.random.seed(seed)
    
    def sample(self):
        LOCATIONs = self.roads.index.to_series()
        
        altered = pd.DataFrame()
        num_to_sample = self.num_samples
        
        while num_to_sample > 0:
            samples = self.accidents[['Timestamp','LOCATION']].sample(n=num_to_sample,replace=True).reset_index()
            sample_Timestamps,sample_LOCATIONs = self._mod(samples.copy(),LOCATIONs,1.0/(self.roads.accident_counts+1))
            # Create an index
            
            Timestamp_strings = sample_Timestamps.map(lambda x:str(int(x.Timestamp()))).values
            LOCATION_strings = sample_LOCATIONs.values.astype('str') 
        
            VEHICLE_NUMBER = Timestamp_strings+LOCATION_strings
            alt = pd.DataFrame({
                'Timestamp': sample_Timestamps.values,
                'LOCATION': sample_LOCATIONs.values,
                'VEHICLE_NUMBER':VEHICLE_NUMBER
            }).set_index('VEHICLE_NUMBER')
            
            altered = altered.append(alt)

            # Which happened before? They shouldn't get negative samples
            intersection = altered.index.intersection(self.accidents.index)
            idxer = intersection.get_values()
            
            # Drop samples where accidents occurred.
            altered = altered.drop(idxer)
            
            num_to_sample = self.num_samples - altered.shape[0]
        
        
        altered['target'] = 0
        
        ts = pd.DatetimeIndex(altered.Timestamp)
        LOCATIONs = altered.LOCATION
        
        #altered = altered.reset_index()
        
        COMMANDs = self.roads.loc[LOCATIONs].COMMAND
        static_features = self.roads.loc[LOCATIONs][self.static_feature_names]
        for i,f in enumerate(self.static_feature_names):
            altered[f] = static_features.values[:,i]
        altered['COMMAND'] = COMMANDs.values
        altered['weekday'] = ts.weekday
        altered['month'] = ts.month
        altered['hour'] = ts.hour
        
        altered = altered.reset_index(drop=True)#.drop(columns=['VEHICLE_NUMBER'])
        return altered
    
    def _mod(self,samples,LOCATIONs,w=None):
        # Get the current Timestamps
        ts = pd.DatetimeIndex(samples.Timestamp)
        
        # Hour, Day, Year
        hour = ts.hour.to_series()
        day = ts.dayofyear.to_series()
        year = ts.year.to_series()

        # Road ID
        LOCATION = samples.LOCATION.copy()
        
        sample_LOCATIONs = pd.Series()
        sample_Timestamps = pd.Series()
                                     
        # Index of samples to mutate
        #feat_i = np.random.randint(0,3,size=samples.shape[0])
        feat_i = np.random.choice([0,1,2],size=samples.shape[0],p=[0.1,0.3,0.6])
        ##########################
        # i == 0
        # Change hour of day
        idx = feat_i == 0
        samp_i = samples.loc[idx]
        N = samp_i.shape[0]

        # Sample until we have all different hours of the day
        num_same = N
        new_hours = hour.loc[idx].values.copy()
        dif_idx = np.ones(N,dtype='bool')
        
        while num_same != 0:
            
            new_hours[dif_idx] = np.random.choice(24,size=num_same)
            dif_idx = new_hours == hour.loc[idx].values
            dif_idx = dif_idx | ((new_hours - 1) == hour.loc[idx].values)
            dif_idx = dif_idx | ((new_hours + 1) == hour.loc[idx].values)
            num_same = dif_idx.sum()
       
        # Create new Timestamps
        new_Timestamps = year[idx].apply(pd.Timestamp,args=(1,1))
        new_Timestamps = pd.DatetimeIndex(new_Timestamps) 
        new_Timestamps += pd.TimedeltaIndex(day[idx]-1,unit='D') # same day
        new_Timestamps += pd.TimedeltaIndex(new_hours,unit='H') # new hour
        
        sample_LOCATIONs = sample_LOCATIONs.append(LOCATION.loc[idx].copy())
        sample_Timestamps = sample_Timestamps.append(new_Timestamps.to_series().copy())
        ##########################

        ##########################
        # i == 1
        # Change day of year
        idx = feat_i == 1
        samp_i = samples.loc[idx]
        N = samp_i.shape[0]

        is_leap_yr = ts[idx].is_leap_year

        # Sample until we have all different days of the year.
        num_same = N
        new_days = day.loc[idx].values.copy()
        dif_idx = np.ones(N,dtype='bool')
        while num_same != 0:
            # Pay attention to leap years
            dif_leap_yr = (dif_idx&is_leap_yr)
            dif_no_leap_yr = dif_idx&(~is_leap_yr)
            
            new_days[dif_leap_yr] = np.random.choice(np.arange(1,367,dtype='int'),size=dif_leap_yr.sum())
            new_days[dif_no_leap_yr] = np.random.choice(np.arange(1,366,dtype='int'),size=dif_no_leap_yr.sum())

            dif_idx = new_days == day.loc[idx].values
            num_same = dif_idx.sum()
        
        # Create new Timestamps
        Timestamps = year[idx].apply(pd.Timestamp,args=(1,1))
        new_Timestamps = pd.DatetimeIndex(Timestamps) 
        new_Timestamps += pd.TimedeltaIndex(new_days-1,unit='D')  # new day
        new_Timestamps += pd.TimedeltaIndex(hour[idx],unit='H') # same hour

        sample_LOCATIONs = sample_LOCATIONs.append(LOCATION.loc[idx].copy())
        sample_Timestamps = sample_Timestamps.append(new_Timestamps.to_series().copy())
        ##########################

        ##########################
        # i == 2
        # Change road
        idx = feat_i == 2
        samp_i = samples.loc[idx]
        N = samp_i.shape[0]

        num_same = N
        new_roads = LOCATION.loc[idx].values.copy()
        dif_idx = np.ones(N,dtype='bool')

        while num_same != 0:
            new_roads[dif_idx] = LOCATIONs.sample(n=num_same,replace=True,weights=w).values
            dif_idx = new_roads == LOCATION.loc[idx].values
            num_same = dif_idx.sum()
        
        sample_LOCATIONs = sample_LOCATIONs.append(pd.Series(new_roads))
        sample_Timestamps = sample_Timestamps.append(ts[idx].to_series().copy())
        
        
        sample_LOCATIONs = sample_LOCATIONs.astype('int64')     
        return sample_Timestamps,sample_LOCATIONs

# %%
import time

t = time.time()
N = made.shape[0]*6
ns = NegativeSampler(N,made,static_feature_names)

negative_examples = ns.sample().set_index(['Timestamp','LOCATION','COMMAND'])

print((time.time() - t),'seconds')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-23cc730f1db4> in <module>
#       3 t = time.time()
#       4 N = made.shape[0]*6
# ----> 5 ns = NegativeSampler(N,made,static_feature_names)
#       6
#       7 negative_examples = ns.sample().set_index(['Timestamp','LOCATION','COMMAND'])
#
# TypeError: __init__() missing 1 required positional argument: 'static_feature_names'
